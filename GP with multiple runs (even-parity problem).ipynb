# %% [markdown]
# # GP Applied to the Even-Parity Problem with multiple runs.

# %% [markdown]
# Now that we understand what's going on at the single-run level, let's modify our code to do multiple runs. Notice the similarity between this code and the sample code for GA with multiple runs.
#
# First, let's widen our display.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# Import our tools.

# %%
import operator
import math
import random

import numpy

from deap import algorithms
from deap import base
from deap import creator
from deap import tools
from deap import gp


import matplotlib.pyplot as plt

import itertools
import networkx as nx

# %% [markdown]
# Set our Genetic Programming parameters, one of which is now the number of runs.

# %%
# Genetic Programming constants:
POPULATION_SIZE = 2000
P_CROSSOVER = 0.9
P_MUTATION = 0.01
MAX_GENERATIONS = 30
HALL_OF_FAME_SIZE = 10

N_RUNS = 30

# %% [markdown]
# Set the random seed.

# %%
RANDOM_SEED = 412
random.seed(RANDOM_SEED)

# %% [markdown]
# GP-Specific constants.

# %%
MIN_TREE_HEIGHT = 3
MAX_TREE_HEIGHT = 5
LIMIT_TREE_HEIGHT = 17
MUT_MIN_TREE_HEIGHT = 0
MUT_MAX_TREE_HEIGHT = 2

# %% [markdown]
# Some problem constants.

# %%
NUM_INPUTS = 6
NUM_COMBINATIONS = 2 ** NUM_INPUTS

# %% [markdown]
# Here's our fitness function. This is a bit more involved than before as we first create all our test cases and then write a function to calculate the party error. We declare a wrapper function, **getCost** to make this code more resuable. This way we can change the fitness function and we only need to change the name in **getCost**.

# %%
# calculate the truth table of even parity check:
parityIn = list(itertools.product([0, 1], repeat=NUM_INPUTS))
parityOut = []
for row in parityIn:
    parityOut.append(sum(row) % 2)
    
# calculate the difference between the results of the
# generated function and the expected parity results:
def parityError(individual):
    func = toolbox.compile(expr=individual)
    return sum(func(*pIn) != pOut for pIn, pOut in zip(parityIn, parityOut))

# fitness measure:
def getCost(individual):
    return parityError(individual), # return a tuple

# %% [markdown]
# Add our functions and terminals. This time we are using Boolean operators and values.

# %%
# create the primitive set:
primitiveSet = gp.PrimitiveSet("main", NUM_INPUTS, "in_")
primitiveSet.addPrimitive(operator.and_, 2)
primitiveSet.addPrimitive(operator.or_, 2)
primitiveSet.addPrimitive(operator.xor, 2)
primitiveSet.addPrimitive(operator.not_, 1)

# add terminal values:
primitiveSet.addTerminal(1)
primitiveSet.addTerminal(0)

# %% [markdown]
# Create our toolbox. This is very similar to the Symbolic Regression notebook except we are using the parameters declared up above.

# %%
toolbox = base.Toolbox()

# define a single objective, minimizing fitness strategy:
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))

# create the Individual class based on the primitive tree:
creator.create("Individual", gp.PrimitiveTree, fitness=creator.FitnessMin)

# create a helper function for creating random trees using the primitive set:
toolbox.register("expr", gp.genFull, pset=primitiveSet, min_=MIN_TREE_HEIGHT, max_=MAX_TREE_HEIGHT)

# create the individual operator to fill up an Individual instance:
toolbox.register("individualCreator", tools.initIterate, creator.Individual, toolbox.expr)

# create the population operator to generate a list of individuals:
toolbox.register("populationCreator", tools.initRepeat, list, toolbox.individualCreator)

# create an operator to compile the primitive tree into python code:
toolbox.register("compile", gp.compile, pset=primitiveSet)

toolbox.register("evaluate", getCost)

# genetic operators:
toolbox.register("select", tools.selTournament, tournsize=2)
toolbox.register("mate", gp.cxOnePoint)
toolbox.register("expr_mut", gp.genGrow, min_=MUT_MIN_TREE_HEIGHT, max_=MUT_MAX_TREE_HEIGHT)
toolbox.register("mutate", gp.mutUniform, expr=toolbox.expr_mut, pset=primitiveSet)

# bloat control:
toolbox.decorate("mate", gp.staticLimit(key=operator.attrgetter("height"), max_value=LIMIT_TREE_HEIGHT))
toolbox.decorate("mutate", gp.staticLimit(key=operator.attrgetter("height"), max_value=LIMIT_TREE_HEIGHT))

# %% [markdown]
# Set up our population as before

# %% [markdown]
# Create our statistics. These are a bit more complex than the GA ones because we want to keep track of fitness and size for all runs.

# %%
maxListFitness = []
avgListFitness = []
minListFitness = []
stdListFitness = []

maxListSize = []
avgListSize = []
minListSize = []
stdListSize = []

# %% [markdown]
# Now the magic happens and we run **N_RUNS** times. Always start with a small number of runs and generations to make sure that everything is working properly before you commit to a larger number. That way, if something goes horribly wrong, Python won't replicate it 30 times before giving you back control!

# %%
for r in range(0, N_RUNS):
    population = toolbox.populationCreator(n=POPULATION_SIZE)
    # define the hall-of-fame object:
    hof = tools.HallOfFame(HALL_OF_FAME_SIZE)   


    # Create our statistics
    stats_fit = tools.Statistics(lambda ind: ind.fitness.values)
    stats_size = tools.Statistics(len)
    mstats = tools.MultiStatistics(fitness=stats_fit, size=stats_size)
    mstats.register("avg", numpy.mean)
    mstats.register("std", numpy.std)
    mstats.register("min", numpy.min)
    mstats.register("max", numpy.max)
    
    
    # Which run are we on?
    print("\n\nCurrently on run", r, "of",N_RUNS)
    
    
    
    population, logbook = algorithms.eaSimple(population,
                                                  toolbox,
                                                  cxpb=P_CROSSOVER,
                                                  mutpb=P_MUTATION,
                                                  ngen=MAX_GENERATIONS,
                                                  stats=mstats,
                                                  halloffame=hof,
                                                  verbose=True)
    
    #maxFitnessValues, meanFitnessValues = logbook.chapters['fitness'].select("min", "avg")
    meanFitnessValues, stdFitnessValues, minFitnessValues, maxFitnessValues  = logbook.chapters['fitness'].select("avg", "std", "min", "max")
    meanSizeValues, stdSizeValues, minSizeValues, maxSizeValues  = logbook.chapters['size'].select("avg", "std", "min", "max")


    # Save statistics for this run:
    avgListFitness.append(meanFitnessValues)
    stdListFitness.append(stdFitnessValues)
    minListFitness.append(minFitnessValues)
    maxListFitness.append(maxFitnessValues)
    
    avgListSize.append(meanSizeValues)
    stdListSize.append(stdSizeValues)
    minListSize.append(minSizeValues)
    maxListSize.append(maxSizeValues)

    # print info for best solution found:
    best = hof.items[0]
    print("-- Best Individual = ", best)
    print("-- length={}, height={}".format(len(best), best.height))
    print("-- Best Fitness = ", best.fitness.values[0])
# Out:
# Currently on run 0 of 30
#    	      	                    fitness                     	                     size
#    	      	------------------------------------------------	----------------------------------------------
# gen	nevals	avg   	gen	max	min	nevals	std     	avg    	gen	max	min	nevals	std
# 0  	2000  	32.009	0  	40 	24 	2000  	0.671505	22.5945	0  	60 	4  	2000  	13.194
# 1  	1816  	31.9305	1  	40 	24 	1816  	0.6969  	23.144 	1  	69 	2  	1816  	14.243
# 2  	1778  	31.8885	2  	40 	16 	1778  	0.924158	24.1045	2  	81 	1  	1778  	15.3416
# 3  	1801  	31.865 	3  	40 	16 	1801  	1.03527 	25.423 	3  	81 	2  	1801  	16.1789
# 4  	1796  	31.791 	4  	40 	22 	1796  	1.12708 	26.556 	4  	92 	2  	1796  	17.4976
# 5  	1817  	31.6685	5  	40 	23 	1817  	1.2902  	27.6965	5  	91 	1  	1817  	18.3071
# 6  	1810  	31.5675	6  	38 	22 	1810  	1.48608 	30.0145	6  	113	2  	1810  	19.427
# 7  	1802  	31.3585	7  	40 	20 	1802  	1.79999 	33.1   	7  	113	2  	1802  	21.2185
# 8  	1802  	31.089 	8  	40 	20 	1802  	2.0727  	38.0255	8  	150	1  	1802  	22.0814
# 9  	1797  	30.835 	9  	40 	22 	1797  	2.27811 	41.5225	9  	144	2  	1797  	22.9631
# 10 	1813  	30.683 	10 	46 	16 	1813  	2.48103 	46.098 	10 	143	1  	1813  	23.016
# 11 	1773  	30.48  	11 	40 	16 	1773  	2.65981 	49.872 	11 	145	1  	1773  	22.8239
# 12 	1817  	30.18  	12 	40 	16 	1817  	2.77229 	54.0065	12 	137	2  	1817  	23.3377
# 13 	1833  	29.7575	13 	45 	16 	1833  	2.99695 	57.8665	13 	166	1  	1833  	23.6264
# 14 	1790  	29.4415	14 	46 	16 	1790  	3.25462 	59.721 	14 	154	1  	1790  	23.7256
# 15 	1812  	29.0685	15 	40 	16 	1812  	3.45004 	62.233 	15 	158	3  	1812  	23.8786
# 16 	1812  	28.551 	16 	40 	16 	1812  	3.52355 	65.4145	16 	173	4  	1812  	24.8963
# 17 	1829  	28.257 	17 	48 	16 	1829  	3.84174 	67.7755	17 	159	3  	1829  	25.8378
# 18 	1824  	27.6665	18 	38 	12 	1824  	3.9592  	70.329 	18 	191	5  	1824  	26.8558
# 19 	1768  	27.344 	19 	44 	10 	1768  	4.32281 	72.7945	19 	193	1  	1768  	28.5554
# 20 	1777  	26.723 	20 	48 	10 	1777  	4.53059 	75.9175	20 	193	3  	1777  	29.2501
# 21 	1820  	26.111 	21 	48 	10 	1820  	4.62587 	78.466 	21 	196	8  	1820  	29.5465
# 22 	1805  	25.5725	22 	48 	8  	1805  	4.78014 	80.6695	22 	196	3  	1805  	31.6797
# 23 	1787  	24.959 	23 	49 	8  	1787  	5.09817 	83.3435	23 	216	3  	1787  	31.384
# 24 	1808  	24.168 	24 	48 	8  	1808  	5.48605 	85.071 	24 	204	3  	1808  	30.6699
# 25 	1825  	23.449 	25 	52 	8  	1825  	5.73048 	87.004 	25 	206	6  	1825  	30.7209
# 26 	1788  	22.772 	26 	48 	10 	1788  	5.8614  	87.2195	26 	206	1  	1788  	29.5055
# 27 	1802  	22.06  	27 	48 	6  	1802  	6.14251 	89.5875	27 	186	1  	1802  	29.0653
# 28 	1780  	21.2665	28 	48 	6  	1780  	6.26223 	90.715 	28 	196	15 	1780  	29.2105
# 29 	1795  	20.7515	29 	48 	6  	1795  	6.55101 	90.332 	29 	219	13 	1795  	29.9565
# 30 	1812  	20.3755	30 	54 	4  	1812  	7.05716 	90.452 	30 	215	12 	1812  	31.1994
# -- Best Individual =  xor(xor(in_2, xor(xor(not_(in_5), and_(in_4, or_(xor(xor(1, or_(not_(in_3), or_(in_0, in_5))), or_(in_5, in_2)), in_3))), xor(and_(in_1, or_(or_(0, in_3), in_0)), and_(in_3, in_0)))), and_(xor(or_(in_5, or_(in_0, xor(or_(not_(in_1), or_(in_2, in_5)), in_5))), or_(in_1, in_3)), and_(xor(in_0, 1), or_(not_(in_3), in_5))))
# -- length=59, height=10
# -- Best Fitness =  4.0
#
#
# Currently on run 1 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg    	gen	max	min	nevals	std     	avg    	gen	max	min	nevals	std
# 0  	2000  	32.0005	0  	40 	24 	2000  	0.677126	23.0675	0  	61 	4  	2000  	13.6871
# 1  	1833  	31.9535	1  	40 	24 	1833  	0.715079	23.126 	1  	79 	1  	1833  	14.1606
# 2  	1816  	31.9195	2  	40 	24 	1816  	0.74298 	23.6865	2  	78 	1  	1816  	14.711
# 3  	1789  	31.883 	3  	40 	24 	1789  	0.897948	24.296 	3  	80 	1  	1789  	15.3574
# 4  	1789  	31.836 	4  	44 	24 	1789  	1.02132 	25.354 	4  	89 	1  	1789  	16.1984
# 5  	1810  	31.8175	5  	46 	22 	1810  	1.0969  	25.7055	5  	88 	1  	1810  	16.558
# 6  	1822  	31.734 	6  	40 	22 	1822  	1.10646 	27.3475	6  	92 	1  	1822  	17.7403
# 7  	1793  	31.715 	7  	40 	24 	1793  	1.16952 	28.9535	7  	96 	1  	1793  	18.9861
# 8  	1825  	31.6125	8  	40 	20 	1825  	1.31124 	31.5305	8  	101	1  	1825  	19.9731
# 9  	1813  	31.4885	9  	40 	16 	1813  	1.47914 	35.446 	9  	114	1  	1813  	21.6298
# 10 	1800  	31.4025	10 	44 	16 	1800  	1.75456 	38.7195	10 	119	1  	1800  	22.4677
# 11 	1795  	31.2425	11 	40 	19 	1795  	1.88672 	42.4595	11 	125	1  	1795  	23.9638
# 12 	1822  	31.081 	12 	40 	19 	1822  	2.04608 	46.896 	12 	126	1  	1822  	25.0373
# 13 	1791  	30.935 	13 	40 	12 	1791  	2.20313 	51.27  	13 	160	1  	1791  	26.3289
# 14 	1798  	30.6825	14 	40 	12 	1798  	2.28423 	55.879 	14 	193	1  	1798  	27.3607
# 15 	1812  	30.5235	15 	41 	8  	1812  	2.44774 	61.379 	15 	159	1  	1812  	27.8621
# 16 	1786  	30.25  	16 	48 	14 	1786  	2.51565 	65.6   	16 	177	1  	1786  	28.6468
# 17 	1812  	29.8935	17 	42 	6  	1812  	2.76191 	69.167 	17 	179	2  	1812  	28.3807
# 18 	1797  	29.658 	18 	42 	11 	1797  	3.0353  	72.5265	18 	177	2  	1797  	27.6843
# 19 	1799  	29.204 	19 	44 	8  	1799  	3.20318 	74.0435	19 	209	1  	1799  	29.1442
# 20 	1824  	28.9695	20 	40 	8  	1824  	3.37869 	77.987 	20 	210	1  	1824  	29.6096
# 21 	1816  	28.5875	21 	44 	4  	1816  	3.73354 	80.6295	21 	203	1  	1816  	29.8703
# 22 	1794  	28.2985	22 	44 	0  	1794  	3.90082 	83.818 	22 	205	2  	1794  	31.5996
# 23 	1780  	27.772 	23 	40 	0  	1780  	4.1839  	86.6515	23 	192	4  	1780  	32.6091
# 24 	1760  	27.238 	24 	53 	0  	1760  	4.56162 	88.8805	24 	202	7  	1760  	33.1178
# 25 	1828  	26.78  	25 	42 	3  	1828  	4.88166 	90.612 	25 	245	3  	1828  	33.6006
# 26 	1819  	26.065 	26 	48 	8  	1819  	5.42252 	93.053 	26 	245	6  	1819  	34.6848
# 27 	1811  	25.562 	27 	44 	0  	1811  	5.55258 	93.557 	27 	245	3  	1811  	34.6553
# 28 	1817  	25.109 	28 	56 	0  	1817  	6.12806 	94.326 	28 	246	3  	1817  	35.9039
# 29 	1815  	24.327 	29 	47 	3  	1815  	6.59083 	96.3845	29 	255	3  	1815  	35.6328
# 30 	1792  	23.4325	30 	50 	0  	1792  	7.07343 	97.938 	30 	220	2  	1792  	34.6733
# -- Best Individual =  or_(not_(1), xor(xor(or_(not_(or_(0, or_(or_(0, 1), in_3))), xor(and_(in_2, in_2), in_4)), or_(in_4, and_(1, in_4))), xor(and_(xor(and_(1, in_5), and_(in_1, 1)), or_(1, in_1)), xor(in_3, xor(in_4, in_0)))))
# -- length=41, height=8
# -- Best Fitness =  0.0
#
#
# Currently on run 2 of 30
#    	      	                    fitness                    	                      size
#    	      	-----------------------------------------------	-----------------------------------------------
# gen	nevals	avg   	gen	max	min	nevals	std    	avg    	gen	max	min	nevals	std
# 0  	2000  	31.982	0  	56 	16 	2000  	0.96264	23.0245	0  	62 	4  	2000  	13.3427
# 1  	1778  	31.924	1  	40 	16 	1778  	0.824757	23.081 	1  	76 	2  	1778  	13.652
# 2  	1785  	31.911	2  	40 	16 	1785  	0.884352	23.4775	2  	91 	2  	1785  	14.3752
# 3  	1821  	31.8995	3  	40 	16 	1821  	0.973858	24.053 	3  	80 	1  	1821  	15.081
# 4  	1799  	31.8725	4  	48 	16 	1799  	1.09692 	24.522 	4  	85 	2  	1799  	15.6
# 5  	1805  	31.819 	5  	40 	16 	1805  	1.06969 	25.442 	5  	92 	1  	1805  	16.256
# 6  	1782  	31.765 	6  	40 	20 	1782  	1.10624 	26.2375	6  	88 	1  	1782  	16.8258
# 7  	1816  	31.6585	7  	40 	20 	1816  	1.39172 	27.879 	7  	87 	1  	1816  	17.8817
# 8  	1842  	31.5505	8  	40 	16 	1842  	1.60326 	30.7185	8  	93 	1  	1842  	18.9114
# 9  	1819  	31.505 	9  	40 	16 	1819  	1.61368 	33.0615	9  	112	1  	1819  	19.7353
# 10 	1796  	31.434 	10 	38 	20 	1796  	1.54585 	35.64  	10 	109	1  	1796  	21.1632
# 11 	1783  	31.319 	11 	41 	18 	1783  	1.67429 	39.373 	11 	108	1  	1783  	22.4591
# 12 	1824  	31.042 	12 	40 	16 	1824  	1.8642  	43.702 	12 	133	1  	1824  	23.3821
# 13 	1790  	30.868 	13 	42 	16 	1790  	2.17637 	49.0305	13 	130	1  	1790  	24.0988
# 14 	1787  	30.553 	14 	38 	16 	1787  	2.3633  	52.682 	14 	146	1  	1787  	24.4896
# 15 	1808  	30.4025	15 	48 	16 	1808  	2.55215 	55.952 	15 	151	1  	1808  	25.0707
# 16 	1791  	30.127 	16 	48 	16 	1791  	2.66643 	59.294 	16 	158	1  	1791  	25.4155
# 17 	1792  	29.7835	17 	49 	14 	1792  	2.86105 	62.626 	17 	197	1  	1792  	25.6505
# 18 	1799  	29.4695	18 	42 	14 	1799  	3.13003 	65.0855	18 	186	2  	1799  	26.8692
# 19 	1826  	29.11  	19 	48 	14 	1826  	3.41949 	69.063 	19 	187	1  	1826  	27.6642
# 20 	1833  	28.868 	20 	48 	12 	1833  	3.73879 	71.9275	20 	205	3  	1833  	28.7486
# 21 	1801  	28.3305	21 	46 	12 	1801  	3.9737  	74.924 	21 	206	1  	1801  	29.7798
# 22 	1819  	27.773 	22 	48 	8  	1819  	4.33514 	77.279 	22 	191	1  	1819  	30.105
# 23 	1814  	27.2065	23 	46 	4  	1814  	4.73274 	79.6915	23 	195	3  	1814  	30.0148
# 24 	1795  	26.4135	24 	46 	0  	1795  	5.30561 	81.292 	24 	198	2  	1795  	30.223
# 25 	1792  	25.5185	25 	45 	3  	1792  	5.86103 	82.88  	25 	199	2  	1792  	30.9381
# 26 	1792  	24.402 	26 	52 	1  	1792  	6.27124 	84.4435	26 	212	5  	1792  	30.4188
# 27 	1800  	23.6545	27 	62 	4  	1800  	6.94278 	85.308 	27 	216	2  	1800  	31.4175
# 28 	1826  	22.818 	28 	48 	4  	1826  	7.07558 	85.387 	28 	233	3  	1826  	31.8562
# 29 	1814  	22.1955	29 	60 	2  	1814  	7.7574  	86.7345	29 	194	3  	1814  	31.3527
# 30 	1811  	21.2345	30 	52 	0  	1811  	7.88445 	87.543 	30 	185	4  	1811  	31.6208
# -- Best Individual =  xor(or_(xor(or_(in_3, xor(not_(and_(in_5, in_3)), and_(and_(in_3, not_(or_(xor(xor(in_2, in_4), and_(in_3, 0)), in_1))), in_3))), not_(and_(in_0, 0))), xor(xor(xor(0, in_5), xor(not_(xor(xor(0, in_5), not_(xor(in_1, in_5)))), in_0)), or_(xor(in_3, in_3), xor(xor(in_2, not_(in_3)), or_(xor(in_4, in_0), xor(not_(in_3), in_3)))))), xor(in_4, 0))
# -- length=64, height=11
# -- Best Fitness =  0.0
#
#
# Currently on run 3 of 30
#    	      	                    fitness                    	                      size
#    	      	-----------------------------------------------	-----------------------------------------------
# gen	nevals	avg   	gen	max	min	nevals	std    	avg   	gen	max	min	nevals	std
# 0  	2000  	32.016	0  	40 	24 	2000  	0.72301	22.997	0  	62 	4  	2000  	13.5749
# 1  	1828  	31.916	1  	40 	24 	1828  	0.685525	22.379	1  	72 	1  	1828  	13.9106
# 2  	1803  	31.8945	2  	38 	24 	1803  	0.758531	23.349	2  	74 	1  	1803  	14.4542
# 3  	1781  	31.8535	3  	44 	24 	1781  	0.970071	23.727	3  	87 	1  	1781  	14.8847
# 4  	1833  	31.8055	4  	38 	16 	1833  	1.16776 	25.0305	4  	77 	1  	1833  	15.7705
# 5  	1780  	31.773 	5  	48 	16 	1780  	1.32871 	26.583 	5  	81 	2  	1780  	16.7649
# 6  	1797  	31.7405	6  	42 	16 	1797  	1.26655 	27.516 	6  	86 	1  	1797  	17.1399
# 7  	1832  	31.6565	7  	56 	16 	1832  	1.52496 	29.3045	7  	96 	1  	1832  	18.3486
# 8  	1785  	31.589 	8  	40 	16 	1785  	1.40466 	30.816 	8  	96 	1  	1785  	19.5607
# 9  	1822  	31.4965	9  	48 	20 	1822  	1.55499 	33.098 	9  	100	1  	1822  	20.5373
# 10 	1797  	31.302 	10 	44 	16 	1797  	1.72852 	36.892 	10 	129	1  	1797  	21.4978
# 11 	1828  	31.2135	11 	40 	16 	1828  	1.88969 	40.9875	11 	128	1  	1828  	22.733
# 12 	1795  	31.042 	12 	40 	16 	1795  	2.03795 	43.956 	12 	147	2  	1795  	23.936
# 13 	1813  	30.911 	13 	41 	20 	1813  	2.0727  	47.235 	13 	167	1  	1813  	24.0779
# 14 	1779  	30.697 	14 	44 	16 	1779  	2.36837 	50.85  	14 	167	1  	1779  	24.6269
# 15 	1803  	30.4735	15 	48 	16 	1803  	2.51998 	55.034 	15 	167	1  	1803  	25.2106
# 16 	1780  	30.2425	16 	40 	16 	1780  	2.56451 	59.4555	16 	182	2  	1780  	25.3774
# 17 	1819  	29.9285	17 	40 	20 	1819  	2.76937 	63.3905	17 	184	1  	1819  	26.5993
# 18 	1785  	29.463 	18 	44 	18 	1785  	3.0649  	67.329 	18 	198	1  	1785  	27.3417
# 19 	1811  	29.116 	19 	42 	16 	1811  	3.33655 	71.4055	19 	204	1  	1811  	28.6031
# 20 	1784  	28.6395	20 	42 	16 	1784  	3.52513 	74.918 	20 	180	3  	1784  	28.6092
# 21 	1823  	28.217 	21 	40 	15 	1823  	3.56748 	78.0625	21 	180	5  	1823  	29.1455
# 22 	1819  	27.972 	22 	44 	15 	1819  	3.80016 	81.282 	22 	206	4  	1819  	29.7735
# 23 	1820  	27.5305	23 	42 	13 	1820  	3.92811 	83.577 	23 	197	7  	1820  	30.1787
# 24 	1803  	27.188 	24 	42 	13 	1803  	4.04421 	86.198 	24 	187	9  	1803  	30.564
# 25 	1779  	26.772 	25 	44 	13 	1779  	4.22351 	89.036 	25 	194	6  	1779  	31.8907
# 26 	1771  	26.1965	26 	44 	12 	1771  	4.30278 	92.9195	26 	209	3  	1771  	32.7945
# 27 	1779  	25.781 	27 	42 	12 	1779  	4.5193  	94.9615	27 	211	6  	1779  	33.5397
# 28 	1825  	25.49  	28 	45 	12 	1825  	4.72947 	96.8415	28 	229	10 	1825  	34.6445
# 29 	1774  	24.844 	29 	44 	12 	1774  	4.88341 	99.3145	29 	266	1  	1774  	36.3939
# 30 	1778  	24.2955	30 	48 	12 	1778  	4.93945 	102.503	30 	262	5  	1778  	37.2494
# -- Best Individual =  xor(or_(and_(xor(not_(xor(and_(in_3, in_2), not_(xor(xor(or_(or_(not_(in_5), in_3), not_(in_2)), in_1), or_(xor(in_3, in_3), in_2))))), in_3), not_(or_(in_2, in_1))), and_(xor(xor(in_5, in_0), and_(in_2, in_3)), or_(not_(in_3), in_3))), not_(xor(or_(and_(in_1, 0), or_(0, in_4)), not_(not_(in_1)))))
# -- length=54, height=12
# -- Best Fitness =  12.0
#
#
# Currently on run 4 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg   	gen	max	min	nevals	std     	avg   	gen	max	min	nevals	std
# 0  	2000  	32.016	0  	40 	24 	2000  	0.793564	22.878	0  	60 	4  	2000  	13.2599
# 1  	1808  	31.932	1  	40 	24 	1808  	0.766405	22.6005	1  	76 	2  	1808  	13.3542
# 2  	1830  	31.9305	2  	40 	24 	1830  	0.771796	22.9465	2  	85 	1  	1830  	13.8262
# 3  	1798  	31.903 	3  	40 	24 	1798  	0.844151	23.6405	3  	85 	1  	1798  	14.6801
# 4  	1842  	31.8875	4  	40 	24 	1842  	0.86478 	23.8755	4  	81 	1  	1842  	14.8272
# 5  	1766  	31.8895	5  	42 	24 	1766  	0.953042	24.438 	5  	84 	1  	1766  	15.6826
# 6  	1766  	31.7855	6  	40 	24 	1766  	0.983611	26.0195	6  	87 	1  	1766  	17.2759
# 7  	1778  	31.7435	7  	40 	24 	1778  	1.13036 	27.7955	7  	99 	1  	1778  	18.5573
# 8  	1830  	31.6385	8  	38 	16 	1830  	1.17806 	30.2605	8  	106	1  	1830  	20.4332
# 9  	1794  	31.577 	9  	40 	24 	1794  	1.30999 	34.312 	9  	117	1  	1794  	21.959
# 10 	1809  	31.449 	10 	42 	20 	1809  	1.43506 	37.965 	10 	123	1  	1809  	23.0084
# 11 	1812  	31.309 	11 	40 	16 	1812  	1.63662 	42.1275	11 	129	1  	1812  	24.009
# 12 	1826  	31.1555	12 	40 	20 	1826  	1.83639 	47.548 	12 	140	1  	1826  	24.4784
# 13 	1807  	30.911 	13 	44 	20 	1807  	1.91052 	52.7365	13 	140	1  	1807  	25.2893
# 14 	1826  	30.6905	14 	48 	16 	1826  	2.11724 	57.7285	14 	152	1  	1826  	25.3186
# 15 	1809  	30.438 	15 	40 	16 	1809  	2.19093 	63.554 	15 	163	2  	1809  	25.8091
# 16 	1828  	30.2125	16 	40 	16 	1828  	2.22224 	67.813 	16 	169	2  	1828  	26.1093
# 17 	1781  	29.9575	17 	40 	16 	1781  	2.42419 	71.438 	17 	181	4  	1781  	27.1156
# 18 	1811  	29.7005	18 	44 	16 	1811  	2.58511 	75.3665	18 	176	5  	1811  	27.4568
# 19 	1833  	29.461 	19 	44 	16 	1833  	2.67011 	77.1535	19 	188	3  	1833  	27.695
# 20 	1802  	29.222 	20 	44 	12 	1802  	2.9034  	80.005 	20 	187	3  	1802  	29.517
# 21 	1817  	28.9865	21 	42 	16 	1817  	3.10537 	83.503 	21 	195	3  	1817  	29.4255
# 22 	1816  	28.6095	22 	48 	14 	1816  	3.29029 	85.9085	22 	181	1  	1816  	29.8508
# 23 	1781  	28.311 	23 	40 	14 	1781  	3.41222 	87.352 	23 	216	1  	1781  	31.5693
# 24 	1808  	27.792 	24 	48 	14 	1808  	3.67909 	89.8245	24 	218	4  	1808  	31.7412
# 25 	1817  	27.366 	25 	48 	14 	1817  	4.13111 	91.9025	25 	212	3  	1817  	32.5622
# 26 	1787  	26.8465	26 	48 	14 	1787  	4.32191 	94.5215	26 	238	7  	1787  	33.2914
# 27 	1784  	26.303 	27 	48 	14 	1784  	4.56072 	97.905 	27 	207	3  	1784  	34.0198
# 28 	1809  	25.632 	28 	48 	12 	1809  	4.84856 	101.335	28 	210	6  	1809  	35.1544
# 29 	1815  	24.7735	29 	48 	12 	1815  	5.27117 	106.252	29 	237	3  	1815  	36.3869
# 30 	1823  	24.104 	30 	48 	12 	1823  	5.50111 	109.945	30 	271	3  	1823  	37.3479
# -- Best Individual =  or_(or_(and_(not_(or_(and_(in_2, 1), in_5)), xor(and_(in_3, 0), xor(in_1, in_1))), not_(or_(in_2, or_(in_3, or_(or_(xor(and_(1, in_1), in_0), and_(or_(in_4, in_3), or_(or_(not_(in_3), in_3), in_4))), and_(0, 1)))))), and_(xor(xor(not_(in_2), in_0), xor(and_(in_3, in_4), xor(in_1, or_(and_(in_4, and_(in_0, 0)), or_(in_5, and_(not_(not_(xor(or_(in_3, and_(in_4, in_0)), in_0))), or_(and_(not_(in_1), 0), in_0))))))), or_(or_(and_(1, in_4), and_(in_3, in_2)), xor(and_(or_(not_(not_(in_0)), and_(or_(in_4, in_0), and_(or_(or_(xor(and_(1, in_1), in_0), and_(or_(in_4, 1), or_(or_(not_(in_3), in_3), in_4))), and_(0, 1)), and_(xor(in_5, in_4), not_(in_3))))), 1), xor(in_2, 0)))))
# -- length=126, height=14
# -- Best Fitness =  12.0
#
#
# Currently on run 5 of 30
#    	      	                    fitness                     	                     size
#    	      	------------------------------------------------	----------------------------------------------
# gen	nevals	avg   	gen	max	min	nevals	std     	avg    	gen	max	min	nevals	std
# 0  	2000  	32.011	0  	40 	24 	2000  	0.896593	23.1165	0  	61 	4  	2000  	13.532
# 1  	1791  	31.9145	1  	36 	24 	1791  	0.721242	23.323 	1  	76 	2  	1791  	14.0822
# 2  	1818  	31.9015	2  	40 	24 	1818  	0.860115	24.7995	2  	90 	2  	1818  	15.1198
# 3  	1810  	31.84  	3  	36 	24 	1810  	0.886228	25.278 	3  	93 	2  	1810  	15.8338
# 4  	1808  	31.8115	4  	40 	24 	1808  	1.03921 	25.965 	4  	108	1  	1808  	16.6993
# 5  	1814  	31.7625	5  	40 	24 	1814  	1.23333 	27.457 	5  	108	1  	1814  	18.3963
# 6  	1803  	31.6805	6  	44 	16 	1803  	1.35034 	29.558 	6  	110	1  	1803  	20.4817
# 7  	1751  	31.543 	7  	40 	16 	1751  	1.45229 	32.9005	7  	113	1  	1751  	22.3578
# 8  	1806  	31.4435	8  	48 	24 	1806  	1.66066 	36.379 	8  	116	1  	1806  	23.739
# 9  	1763  	31.2445	9  	40 	18 	1763  	1.74778 	40.203 	9  	164	1  	1763  	25.1459
# 10 	1800  	31.144 	10 	40 	20 	1800  	1.82928 	44.581 	10 	167	1  	1800  	26.4478
# 11 	1799  	30.947 	11 	44 	20 	1799  	2.0013  	50.332 	11 	198	1  	1799  	28.2744
# 12 	1780  	30.669 	12 	44 	18 	1780  	2.18482 	57.864 	12 	192	2  	1780  	29.4457
# 13 	1817  	30.449 	13 	44 	18 	1817  	2.3663  	63.795 	13 	192	2  	1817  	30.1014
# 14 	1810  	30.1035	14 	44 	18 	1810  	2.54259 	67.6455	14 	190	1  	1810  	30.2125
# 15 	1796  	29.861 	15 	43 	16 	1796  	2.62596 	70.9525	15 	200	1  	1796  	30.5199
# 16 	1775  	29.46  	16 	48 	12 	1775  	2.87983 	76.4655	16 	202	2  	1775  	31.8305
# 17 	1824  	29.169 	17 	42 	14 	1824  	3.13503 	79.45  	17 	204	2  	1824  	31.143
# 18 	1791  	28.717 	18 	48 	14 	1791  	3.28739 	82.2945	18 	222	1  	1791  	32.1776
# 19 	1838  	28.3195	19 	48 	12 	1838  	3.62607 	84.5055	19 	223	7  	1838  	32.7807
# 20 	1783  	27.9655	20 	52 	12 	1783  	4.02583 	84.6025	20 	240	3  	1783  	31.8999
# 21 	1782  	27.572 	21 	44 	12 	1782  	4.17634 	84.5805	21 	222	5  	1782  	32.6425
# 22 	1797  	27.2305	22 	50 	12 	1797  	4.35871 	85.795 	22 	224	7  	1797  	32.6248
# 23 	1807  	26.679 	23 	48 	12 	1807  	4.66476 	86.99  	23 	207	5  	1807  	31.6338
# 24 	1845  	26.103 	24 	44 	12 	1845  	4.93907 	87.435 	24 	208	3  	1845  	31.4173
# 25 	1804  	25.457 	25 	46 	0  	1804  	5.3466  	87.807 	25 	221	8  	1804  	32.2934
# 26 	1803  	24.753 	26 	48 	0  	1803  	5.60116 	89.188 	26 	221	5  	1803  	33.1833
# 27 	1817  	24.089 	27 	50 	0  	1817  	6.10509 	90.4225	27 	215	3  	1817  	34.7907
# 28 	1800  	23.1535	28 	52 	0  	1800  	6.39147 	92.561 	28 	215	3  	1800  	35.4629
# 29 	1789  	22.3845	29 	48 	0  	1789  	6.45497 	93.032 	29 	208	1  	1789  	35.5904
# 30 	1811  	21.737 	30 	48 	0  	1811  	6.67157 	92.439 	30 	228	1  	1811  	36.0301
# -- Best Individual =  xor(or_(not_(or_(xor(xor(not_(in_3), xor(in_4, in_0)), not_(or_(in_5, 1))), xor(not_(or_(in_2, in_1)), in_1))), xor(or_(in_2, in_0), not_(1))), xor(in_5, xor(xor(or_(0, xor(not_(or_(not_(in_2), not_(in_0))), in_3)), and_(or_(and_(in_1, and_(in_2, in_5)), in_1), in_1)), not_(not_(in_4)))))
# -- length=53, height=9
# -- Best Fitness =  0.0
#
#
# Currently on run 6 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg   	gen	max	min	nevals	std     	avg   	gen	max	min	nevals	std
# 0  	2000  	32.009	0  	48 	24 	2000  	0.821535	23.021	0  	60 	4  	2000  	13.2219
# 1  	1791  	31.968	1  	40 	24 	1791  	0.648827	23.0865	1  	69 	1  	1791  	13.838
# 2  	1786  	31.9405	2  	40 	24 	1786  	0.653422	23.461 	2  	79 	1  	1786  	14.2397
# 3  	1824  	31.911 	3  	40 	24 	1824  	0.718386	24.229 	3  	87 	1  	1824  	15.4724
# 4  	1802  	31.858 	4  	36 	22 	1802  	0.844296	25.1875	4  	85 	1  	1802  	15.9944
# 5  	1794  	31.833 	5  	44 	24 	1794  	1.00901 	26.5865	5  	91 	1  	1794  	17.2249
# 6  	1802  	31.815 	6  	40 	24 	1802  	1.02312 	27.482 	6  	128	1  	1802  	18.3049
# 7  	1783  	31.7765	7  	40 	24 	1783  	1.05761 	28.947 	7  	134	1  	1783  	19.018
# 8  	1787  	31.711 	8  	40 	23 	1787  	1.1236  	30.443 	8  	134	1  	1787  	20.4948
# 9  	1795  	31.5925	9  	48 	20 	1795  	1.35515 	33.889 	9  	115	1  	1795  	22.0733
# 10 	1806  	31.5255	10 	40 	23 	1806  	1.32074 	37.742 	10 	131	1  	1806  	23.2986
# 11 	1823  	31.4475	11 	40 	23 	1823  	1.36684 	41.506 	11 	133	1  	1823  	25.2465
# 12 	1821  	31.276 	12 	39 	20 	1821  	1.5874  	45.8375	12 	142	1  	1821  	26.0336
# 13 	1774  	31.072 	13 	40 	20 	1774  	1.76856 	50.419 	13 	141	1  	1774  	26.6953
# 14 	1788  	30.8635	14 	38 	22 	1788  	1.84685 	55.9875	14 	154	1  	1788  	27.1378
# 15 	1806  	30.6495	15 	44 	22 	1806  	2.08438 	61.6495	15 	166	1  	1806  	27.4925
# 16 	1834  	30.4365	16 	48 	16 	1834  	2.29281 	66.294 	16 	175	1  	1834  	27.8167
# 17 	1776  	30.185 	17 	40 	16 	1776  	2.40058 	69.5365	17 	151	1  	1776  	28.6486
# 18 	1794  	29.9235	18 	40 	16 	1794  	2.62367 	72.93  	18 	178	3  	1794  	28.8601
# 19 	1808  	29.6515	19 	42 	16 	1808  	2.80643 	76.766 	19 	188	2  	1808  	28.6648
# 20 	1821  	29.347 	20 	42 	16 	1821  	2.86244 	79.856 	20 	201	1  	1821  	30.0017
# 21 	1816  	29.0255	21 	42 	16 	1816  	3.01162 	82.5455	21 	201	1  	1816  	30.2989
# 22 	1823  	28.764 	22 	46 	16 	1823  	3.29883 	86.364 	22 	208	1  	1823  	31.4637
# 23 	1805  	28.3715	23 	43 	16 	1805  	3.46504 	89.068 	23 	210	5  	1805  	32.4003
# 24 	1789  	27.8635	24 	41 	16 	1789  	3.52461 	90.7255	24 	191	3  	1789  	32.4186
# 25 	1819  	27.4065	25 	44 	16 	1819  	3.76235 	92.4755	25 	211	3  	1819  	32.6887
# 26 	1790  	27.0955	26 	44 	16 	1790  	4.00941 	94.0525	26 	207	5  	1790  	33.2218
# 27 	1806  	26.747 	27 	48 	16 	1806  	4.15403 	94.954 	27 	229	1  	1806  	33.6726
# 28 	1782  	26.403 	28 	43 	16 	1782  	4.16972 	95.65  	28 	245	1  	1782  	35.2349
# 29 	1799  	26.06  	29 	48 	16 	1799  	4.29237 	99.0555	29 	258	3  	1799  	35.8629
# 30 	1826  	25.7395	30 	46 	8  	1826  	4.36447 	102.522	30 	229	5  	1826  	36.7126
# -- Best Individual =  xor(and_(or_(in_5, in_4), xor(and_(in_4, and_(in_3, 0)), xor(xor(or_(0, xor(xor(in_0, in_3), in_1)), not_(not_(not_(in_2)))), and_(in_5, in_4)))), and_(and_(and_(and_(not_(or_(xor(in_4, or_(1, in_2)), in_4)), in_3), not_(xor(in_0, in_5))), and_(and_(in_0, in_2), xor(in_0, in_5))), and_(not_(not_(1)), xor(or_(in_4, 0), not_(in_5)))))
# -- length=61, height=9
# -- Best Fitness =  8.0
#
#
# Currently on run 7 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg    	gen	max	min	nevals	std     	avg    	gen	max	min	nevals	std
# 0  	2000  	31.9895	0  	40 	26 	2000  	0.648375	23.2585	0  	62 	4  	2000  	13.3511
# 1  	1762  	31.919 	1  	40 	24 	1762  	0.71515 	23.5195	1  	76 	2  	1762  	13.7927
# 2  	1811  	31.8645	2  	36 	24 	1811  	0.84151 	24.4295	2  	87 	1  	1811  	14.8331
# 3  	1828  	31.819 	3  	40 	20 	1828  	0.99108 	26.0645	3  	93 	1  	1828  	16.1905
# 4  	1837  	31.732 	4  	40 	20 	1837  	1.19506 	28.3435	4  	105	2  	1837  	17.6821
# 5  	1815  	31.6665	5  	40 	20 	1815  	1.32487 	30.4105	5  	140	2  	1815  	18.9598
# 6  	1797  	31.647 	6  	48 	20 	1797  	1.4998  	32.693 	6  	140	1  	1797  	20.8505
# 7  	1803  	31.5025	7  	40 	20 	1803  	1.58335 	36.304 	7  	138	2  	1803  	22.8676
# 8  	1785  	31.4055	8  	44 	20 	1785  	1.72571 	40.1015	8  	137	1  	1785  	25.0823
# 9  	1833  	31.212 	9  	38 	20 	1833  	1.7925  	44.853 	9  	137	1  	1833  	27.011
# 10 	1803  	31.085 	10 	44 	20 	1803  	2.06198 	52.0315	10 	151	1  	1803  	28.9111
# 11 	1811  	30.8865	11 	41 	16 	1811  	2.21373 	57.3605	11 	181	2  	1811  	29.906
# 12 	1770  	30.718 	12 	41 	16 	1770  	2.35743 	63.3995	12 	165	2  	1770  	30.864
# 13 	1797  	30.3835	13 	42 	16 	1797  	2.43443 	70.2365	13 	195	2  	1797  	31.5029
# 14 	1803  	30.144 	14 	44 	8  	1803  	2.65768 	75.323 	14 	219	3  	1803  	31.905
# 15 	1797  	29.789 	15 	48 	8  	1797  	2.98001 	79.9355	15 	239	3  	1797  	31.7757
# 16 	1816  	29.5485	16 	44 	8  	1816  	3.19087 	81.7645	16 	214	3  	1816  	30.9686
# 17 	1817  	29.1515	17 	50 	8  	1817  	3.5934  	84.7355	17 	249	2  	1817  	31.0108
# 18 	1775  	28.7325	18 	44 	8  	1775  	3.69756 	87.88  	18 	242	3  	1775  	31.7753
# 19 	1831  	28.3665	19 	44 	12 	1831  	3.95198 	90.448 	19 	260	2  	1831  	31.6404
# 20 	1808  	27.7795	20 	48 	8  	1808  	4.21603 	93.693 	20 	242	7  	1808  	32.6027
# 21 	1802  	27.2415	21 	48 	8  	1802  	4.5732  	95.9055	21 	244	8  	1802  	33.1527
# 22 	1818  	26.764 	22 	48 	8  	1818  	5.08629 	95.698 	22 	246	1  	1818  	33.6802
# 23 	1821  	26.071 	23 	48 	8  	1821  	5.22618 	96.1185	23 	241	10 	1821  	34.2139
# 24 	1790  	25.389 	24 	56 	8  	1790  	5.82054 	95.5645	24 	257	3  	1790  	35.2669
# 25 	1791  	24.5585	25 	48 	4  	1791  	6.32926 	95.398 	25 	240	3  	1791  	34.6596
# 26 	1806  	23.6645	26 	48 	4  	1806  	6.66558 	95.415 	26 	240	6  	1806  	35.8382
# 27 	1833  	22.7705	27 	48 	0  	1833  	7.17703 	93.1325	27 	240	2  	1833  	36.0935
# 28 	1820  	21.9085	28 	52 	0  	1820  	7.77953 	90.546 	28 	258	7  	1820  	36.8385
# 29 	1802  	21.25  	29 	64 	0  	1802  	7.84732 	87.319 	29 	245	1  	1802  	35.7831
# 30 	1787  	20.6165	30 	64 	0  	1787  	8.41632 	86.4425	30 	259	7  	1787  	34.5237
# -- Best Individual =  xor(xor(or_(not_(or_(xor(or_(and_(1, not_(xor(in_2, in_4))), in_4), and_(xor(or_(or_(and_(in_4, in_2), in_4), not_(and_(in_5, 1))), in_1), xor(1, in_5))), xor(and_(and_(in_5, in_4), and_(in_0, in_4)), or_(or_(in_0, not_(xor(not_(in_3), xor(1, xor(and_(in_2, in_3), and_(or_(in_5, xor(in_1, in_3)), 0)))))), xor(in_5, in_4))))), or_(xor(in_4, xor(in_0, in_0)), or_(not_(in_0), 0))), xor(in_2, not_(not_(in_3)))), not_(xor(xor(in_1, and_(in_4, in_0)), xor(in_5, and_(in_4, in_4)))))
# -- length=88, height=15
# -- Best Fitness =  0.0
#
#
# Currently on run 8 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg   	gen	max	min	nevals	std     	avg   	gen	max	min	nevals	std
# 0  	2000  	32.002	0  	40 	22 	2000  	0.745651	22.578	0  	62 	4  	2000  	13.4206
# 1  	1813  	31.924	1  	40 	16 	1813  	0.769561	22.736	1  	75 	1  	1813  	13.9107
# 2  	1804  	31.889	2  	40 	16 	1804  	1.00234 	23.777	2  	82 	1  	1804  	14.9486
# 3  	1810  	31.848	3  	48 	16 	1810  	1.08393 	25.2105	3  	84 	1  	1810  	16.2546
# 4  	1797  	31.783	4  	48 	18 	1797  	1.16143 	26.7635	4  	87 	1  	1797  	17.5664
# 5  	1783  	31.657	5  	40 	18 	1783  	1.2745  	28.4195	5  	95 	1  	1783  	18.9512
# 6  	1828  	31.5715	6  	40 	18 	1828  	1.52082 	31.3475	6  	114	1  	1828  	20.5383
# 7  	1810  	31.512 	7  	40 	16 	1810  	1.65857 	33.263 	7  	111	1  	1810  	21.7597
# 8  	1780  	31.2785	8  	48 	16 	1780  	1.95753 	36.45  	8  	121	1  	1780  	22.8586
# 9  	1824  	31.21  	9  	38 	16 	1824  	2.02803 	40.206 	9  	125	1  	1824  	23.2732
# 10 	1806  	30.975 	10 	40 	16 	1806  	2.26172 	44.0505	10 	140	2  	1806  	24.3797
# 11 	1833  	30.6805	11 	40 	0  	1833  	2.66372 	48.8335	11 	146	2  	1833  	24.047
# 12 	1825  	30.362 	12 	48 	0  	1825  	3.11223 	52.6325	12 	158	2  	1825  	24.2128
# 13 	1814  	30.048 	13 	44 	0  	1814  	3.42209 	56.9625	13 	162	2  	1814  	23.7051
# 14 	1832  	29.716 	14 	56 	0  	1832  	3.69437 	60.368 	14 	172	2  	1832  	24.5817
# 15 	1820  	29.08  	15 	40 	0  	1820  	3.97977 	63.68  	15 	196	2  	1820  	25.3843
# 16 	1792  	28.565 	16 	48 	0  	1792  	4.49664 	65.43  	16 	232	3  	1792  	25.9268
# 17 	1807  	28.332 	17 	64 	0  	1807  	4.71166 	66.9835	17 	185	3  	1807  	26.2282
# 18 	1795  	27.6165	18 	48 	0  	1795  	5.08325 	68.611 	18 	185	2  	1795  	27.2784
# 19 	1784  	27.2325	19 	48 	0  	1784  	5.18473 	69.499 	19 	222	3  	1784  	27.873
# 20 	1822  	26.581 	20 	56 	0  	1822  	5.53999 	71.2335	20 	179	3  	1822  	28.1699
# 21 	1839  	26.1945	21 	56 	0  	1839  	5.76539 	72.8695	21 	186	1  	1839  	28.1354
# 22 	1806  	25.6315	22 	48 	0  	1806  	6.05365 	74.212 	22 	211	1  	1806  	28.3569
# 23 	1801  	24.9735	23 	48 	0  	1801  	6.41177 	75.3765	23 	269	3  	1801  	28.998
# 24 	1808  	24.3665	24 	49 	0  	1808  	6.69322 	77.018 	24 	271	4  	1808  	30.1392
# 25 	1831  	23.7545	25 	64 	0  	1831  	7.27401 	77.6555	25 	188	9  	1831  	29.4731
# 26 	1810  	22.8355	26 	64 	0  	1810  	7.91413 	80.3775	26 	211	4  	1810  	30.0505
# 27 	1820  	21.781 	27 	64 	0  	1820  	8.68556 	83.0485	27 	197	3  	1820  	30.855
# 28 	1784  	20.49  	28 	64 	0  	1784  	9.55138 	88.1585	28 	251	8  	1784  	31.6402
# 29 	1826  	19.106 	29 	56 	0  	1826  	10.2176 	90.7565	29 	199	10 	1826  	31.858
# 30 	1783  	17.0395	30 	49 	0  	1783  	10.7511 	94.315 	30 	201	1  	1783  	34.5439
# -- Best Individual =  xor(not_(or_(and_(xor(in_0, in_1), or_(in_1, 1)), not_(not_(xor(in_0, in_1))))), xor(and_(0, xor(or_(xor(0, 1), xor(1, in_4)), or_(xor(in_4, in_3), not_(and_(not_(or_(in_0, in_1)), xor(or_(not_(in_2), or_(1, not_(in_3))), and_(1, in_1))))))), xor(xor(not_(in_3), and_(in_4, in_4)), xor(0, xor(in_5, in_2)))))
# -- length=59, height=11
# -- Best Fitness =  0.0
#
#
# Currently on run 9 of 30
#    	      	                    fitness                    	                      size
#    	      	-----------------------------------------------	-----------------------------------------------
# gen	nevals	avg   	gen	max	min	nevals	std    	avg   	gen	max	min	nevals	std
# 0  	2000  	32.014	0  	52 	16 	2000  	1.01873	23.525	0  	60 	4  	2000  	13.8199
# 1  	1818  	31.9215	1  	40 	16 	1818  	0.774169	23.366	1  	70 	2  	1818  	14.3547
# 2  	1819  	31.9105	2  	48 	24 	1819  	0.891902	23.933	2  	81 	1  	1819  	14.8093
# 3  	1766  	31.8725	3  	40 	16 	1766  	1.11097 	24.733	3  	84 	1  	1766  	15.4093
# 4  	1809  	31.8555	4  	40 	16 	1809  	1.10572 	26.08 	4  	92 	1  	1809  	16.207
# 5  	1817  	31.7375	5  	36 	16 	1817  	1.29097 	27.2815	5  	98 	2  	1817  	17.2166
# 6  	1785  	31.666 	6  	40 	16 	1785  	1.47358 	28.942 	6  	109	1  	1785  	18.7628
# 7  	1786  	31.615 	7  	44 	16 	1786  	1.54168 	30.29  	7  	115	1  	1786  	19.6153
# 8  	1806  	31.509 	8  	48 	16 	1806  	1.70262 	33.1585	8  	125	1  	1806  	21.0814
# 9  	1761  	31.333 	9  	40 	16 	1761  	1.82568 	36.954 	9  	136	1  	1761  	22.1306
# 10 	1756  	31.1875	10 	40 	18 	1756  	2.00159 	41.4205	10 	146	1  	1756  	23.043
# 11 	1830  	30.9325	11 	42 	18 	1830  	2.25963 	45.913 	11 	147	1  	1830  	23.4339
# 12 	1798  	30.672 	12 	44 	16 	1798  	2.49227 	49.888 	12 	139	1  	1798  	24.3028
# 13 	1794  	30.2005	13 	40 	12 	1794  	2.82512 	54.175 	13 	147	1  	1794  	24.6351
# 14 	1825  	29.8655	14 	44 	12 	1825  	3.09732 	58.5175	14 	167	1  	1825  	24.31
# 15 	1791  	29.3475	15 	43 	12 	1791  	3.37709 	62.023 	15 	158	1  	1791  	23.9284
# 16 	1794  	28.8615	16 	48 	14 	1794  	3.65518 	64.2445	16 	171	3  	1794  	25.1325
# 17 	1793  	28.206 	17 	48 	16 	1793  	3.89622 	66.2815	17 	171	3  	1793  	26.1689
# 18 	1837  	27.6305	18 	44 	16 	1837  	4.11934 	67.864 	18 	171	3  	1837  	27.9903
# 19 	1817  	27.097 	19 	48 	12 	1817  	4.44799 	68.395 	19 	182	3  	1817  	28.067
# 20 	1799  	26.4725	20 	44 	15 	1799  	4.55491 	70.1565	20 	166	1  	1799  	28.2512
# 21 	1814  	25.561 	21 	48 	15 	1814  	4.58468 	71.832 	21 	186	3  	1814  	29.2826
# 22 	1811  	25.3405	22 	48 	14 	1811  	4.86226 	72.595 	22 	167	3  	1811  	29.8544
# 23 	1779  	24.7985	23 	48 	8  	1779  	5.04221 	74.3695	23 	203	5  	1779  	30.6882
# 24 	1821  	24.4575	24 	44 	8  	1821  	5.21164 	74.81  	24 	238	4  	1821  	31.4644
# 25 	1803  	24.1915	25 	44 	8  	1803  	5.23334 	75.9295	25 	238	2  	1803  	31.368
# 26 	1797  	23.8105	26 	45 	12 	1797  	5.3502  	75.942 	26 	238	1  	1797  	31.2163
# 27 	1800  	23.152 	27 	47 	8  	1800  	5.39832 	75.296 	27 	231	3  	1800  	31.9237
# 28 	1807  	22.7075	28 	48 	8  	1807  	5.60633 	76.2375	28 	214	1  	1807  	31.9597
# 29 	1784  	22.1855	29 	49 	8  	1784  	5.85116 	79.6185	29 	214	1  	1784  	33.1091
# 30 	1824  	21.9525	30 	48 	8  	1824  	6.12358 	80.6625	30 	233	1  	1824  	34.5647
# -- Best Individual =  xor(xor(and_(or_(1, 1), xor(in_3, in_0)), or_(xor(xor(and_(not_(0), or_(in_4, or_(in_4, xor(in_1, in_1)))), or_(in_1, xor(in_1, in_5))), and_(1, or_(not_(in_2), not_(or_(not_(and_(xor(xor(in_4, in_3), xor(not_(in_2), or_(in_4, in_1))), in_0)), or_(xor(in_3, in_5), xor(in_2, 0))))))), not_(in_2))), xor(or_(not_(in_5), or_(and_(and_(in_0, and_(xor(or_(xor(not_(in_5), not_(in_4)), xor(or_(1, in_2), in_1)), xor(in_1, in_0)), in_1)), and_(not_(in_2), not_(not_(0)))), in_1)), and_(or_(in_4, in_2), in_5)))
# -- length=93, height=13
# -- Best Fitness =  8.0
#
#
# Currently on run 10 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg   	gen	max	min	nevals	std     	avg   	gen	max	min	nevals	std
# 0  	2000  	32.005	0  	44 	16 	2000  	0.773288	22.816	0  	63 	4  	2000  	13.4956
# 1  	1775  	31.9395	1  	48 	16 	1775  	0.898799	22.4135	1  	75 	1  	1775  	13.689
# 2  	1786  	31.9005	2  	44 	16 	1786  	0.96312 	23.172 	2  	84 	1  	1786  	14.7313
# 3  	1796  	31.8965	3  	48 	22 	1796  	0.969427	24.2495	3  	99 	1  	1796  	15.9034
# 4  	1786  	31.817 	4  	40 	22 	1786  	1.00574 	24.948 	4  	106	1  	1786  	17.0813
# 5  	1835  	31.769 	5  	40 	22 	1835  	1.11384 	26.334 	5  	106	1  	1835  	17.8439
# 6  	1834  	31.713 	6  	38 	22 	1834  	1.18938 	27.7495	6  	96 	1  	1834  	18.7752
# 7  	1813  	31.6405	7  	42 	22 	1813  	1.39365 	30.6755	7  	99 	1  	1813  	20.1777
# 8  	1811  	31.517 	8  	38 	20 	1811  	1.5449  	33.6015	8  	110	1  	1811  	21.5776
# 9  	1789  	31.364 	9  	40 	20 	1789  	1.73652 	37.74  	9  	123	1  	1789  	23.1308
# 10 	1824  	31.244 	10 	48 	20 	1824  	1.95537 	40.8135	10 	150	1  	1824  	24.327
# 11 	1800  	30.9815	11 	40 	20 	1800  	2.11191 	46.217 	11 	148	1  	1800  	25.6889
# 12 	1814  	30.7145	12 	38 	16 	1814  	2.22688 	52.21  	12 	151	1  	1814  	26.3642
# 13 	1819  	30.3855	13 	46 	16 	1819  	2.59729 	58.6425	13 	151	1  	1819  	26.526
# 14 	1793  	30.0075	14 	48 	16 	1793  	2.8598  	64.0485	14 	174	1  	1793  	27.8033
# 15 	1778  	29.6525	15 	44 	16 	1778  	3.02254 	68.865 	15 	187	1  	1778  	27.4394
# 16 	1789  	29.3495	16 	42 	16 	1789  	3.13374 	73.8355	16 	192	1  	1789  	28.1615
# 17 	1781  	28.9075	17 	40 	16 	1781  	3.35558 	77.886 	17 	194	1  	1781  	28.2137
# 18 	1810  	28.423 	18 	40 	8  	1810  	3.63883 	81.57  	18 	201	11 	1810  	28.719
# 19 	1803  	27.94  	19 	48 	8  	1803  	3.81253 	82.5535	19 	210	4  	1803  	29.6621
# 20 	1809  	27.4825	20 	48 	8  	1809  	4.07513 	85.3795	20 	201	3  	1809  	31.454
# 21 	1782  	27.0845	21 	56 	8  	1782  	4.31015 	87.691 	21 	242	6  	1782  	32.0098
# 22 	1829  	26.7265	22 	48 	10 	1829  	4.52821 	90.4825	22 	245	7  	1829  	32.9981
# 23 	1798  	26.0405	23 	48 	10 	1798  	4.73443 	93.61  	23 	214	10 	1798  	33.5311
# 24 	1813  	25.5815	24 	48 	10 	1813  	5.14231 	95.299 	24 	220	8  	1813  	34.0078
# 25 	1764  	24.8105	25 	48 	8  	1764  	5.33466 	96.203 	25 	234	5  	1764  	34.1467
# 26 	1823  	24.567 	26 	54 	4  	1823  	5.79677 	98.1485	26 	240	3  	1823  	35.2851
# 27 	1781  	23.921 	27 	48 	2  	1781  	6.05151 	98.613 	27 	261	3  	1781  	35.3575
# 28 	1790  	23.321 	28 	50 	2  	1790  	6.42106 	100.794	28 	230	9  	1790  	35.458
# 29 	1787  	22.5545	29 	54 	2  	1787  	6.80324 	102.442	29 	230	9  	1787  	35.5677
# 30 	1800  	22.1675	30 	54 	2  	1800  	7.3775  	102.5  	30 	235	3  	1800  	35.9501
# -- Best Individual =  xor(xor(xor(not_(in_1), xor(1, in_1)), xor(and_(or_(or_(and_(or_(and_(xor(in_2, in_4), in_0), xor(or_(0, in_0), and_(in_5, in_4))), xor(0, in_2)), not_(in_2)), in_1), xor(in_4, in_0)), xor(in_2, 1))), not_(xor(xor(not_(in_1), and_(not_(not_(or_(or_(xor(not_(or_(and_(in_0, in_0), xor(in_0, in_1))), or_(and_(xor(or_(in_1, in_5), in_4), and_(0, in_1)), not_(or_(in_4, in_4)))), not_(not_(not_(xor(in_4, xor(in_1, in_4)))))), in_1))), not_(in_5))), in_3)))
# -- length=83, height=14
# -- Best Fitness =  2.0
#
#
# Currently on run 11 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg   	gen	max	min	nevals	std     	avg    	gen	max	min	nevals	std
# 0  	2000  	32.038	0  	40 	24 	2000  	0.724952	22.6105	0  	61 	4  	2000  	13.2139
# 1  	1800  	31.935	1  	41 	16 	1800  	0.742816	22.534 	1  	68 	1  	1800  	13.7143
# 2  	1770  	31.9065	2  	48 	16 	1770  	0.908162	22.707 	2  	78 	1  	1770  	14.9112
# 3  	1791  	31.8985	3  	40 	24 	1791  	0.780511	23.332 	3  	75 	1  	1791  	15.0985
# 4  	1811  	31.8705	4  	40 	24 	1811  	0.870477	23.5275	4  	84 	1  	1811  	15.565
# 5  	1778  	31.827 	5  	40 	18 	1778  	0.951878	25.0675	5  	93 	1  	1778  	16.6672
# 6  	1786  	31.7925	6  	40 	24 	1786  	0.911835	25.9875	6  	94 	1  	1786  	17.2597
# 7  	1823  	31.7605	7  	44 	24 	1823  	1.1172  	27.8755	7  	106	1  	1823  	17.9591
# 8  	1816  	31.6955	8  	38 	24 	1816  	1.22057 	29.4185	8  	120	1  	1816  	18.5771
# 9  	1818  	31.6105	9  	40 	23 	1818  	1.31179 	31.985 	9  	120	1  	1818  	19.4607
# 10 	1779  	31.535 	10 	44 	24 	1779  	1.4042  	34.301 	10 	125	1  	1779  	20.9078
# 11 	1771  	31.4555	11 	42 	24 	1771  	1.51625 	37.9915	11 	126	1  	1771  	22.3007
# 12 	1814  	31.292 	12 	38 	22 	1814  	1.6534  	41.7765	12 	125	1  	1814  	23.8372
# 13 	1807  	31.0495	13 	40 	22 	1807  	1.84365 	45.493 	13 	160	1  	1807  	24.7635
# 14 	1811  	30.866 	14 	41 	22 	1811  	2.08735 	49.815 	14 	155	1  	1811  	25.4395
# 15 	1820  	30.578 	15 	48 	22 	1820  	2.24831 	54.6555	15 	154	1  	1820  	26.5936
# 16 	1819  	30.3535	16 	48 	21 	1819  	2.34873 	58.325 	16 	154	1  	1819  	27.2913
# 17 	1790  	29.989 	17 	44 	20 	1790  	2.55262 	62.774 	17 	171	1  	1790  	27.5814
# 18 	1827  	29.667 	18 	41 	20 	1827  	2.64161 	66.1355	18 	181	2  	1827  	27.6922
# 19 	1792  	29.4405	19 	42 	19 	1792  	2.9006  	69.1465	19 	180	2  	1792  	27.9034
# 20 	1804  	29.242 	20 	48 	19 	1804  	3.01089 	70.9025	20 	184	3  	1804  	28.5577
# 21 	1787  	29.0085	21 	40 	18 	1787  	3.14761 	74.2325	21 	223	3  	1787  	29.3396
# 22 	1816  	28.7885	22 	44 	18 	1816  	3.28782 	76.3625	22 	183	1  	1816  	29.0718
# 23 	1808  	28.2625	23 	40 	16 	1808  	3.28612 	80.3145	23 	186	1  	1808  	29.4065
# 24 	1805  	27.871 	24 	40 	15 	1805  	3.2908  	82.978 	24 	188	1  	1805  	29.128
# 25 	1770  	27.727 	25 	40 	15 	1770  	3.50863 	84.2205	25 	205	1  	1770  	30.4002
# 26 	1787  	27.312 	26 	40 	4  	1787  	3.62431 	86.1705	26 	209	3  	1787  	30.1545
# 27 	1800  	26.937 	27 	42 	4  	1800  	3.77148 	88.036 	27 	207	3  	1800  	30.251
# 28 	1802  	26.7785	28 	43 	12 	1802  	3.82511 	89.5965	28 	230	1  	1802  	29.5811
# 29 	1796  	26.609 	29 	44 	12 	1796  	3.96965 	90.512 	29 	219	3  	1796  	30.3717
# 30 	1794  	26.439 	30 	44 	12 	1794  	4.06882 	92.649 	30 	207	3  	1794  	30.4841
# -- Best Individual =  xor(or_(xor(or_(or_(or_(in_5, and_(or_(in_5, xor(in_3, in_5)), and_(in_5, in_3))), or_(in_1, in_5)), not_(0)), 1), xor(not_(not_(0)), xor(xor(in_0, xor(in_1, not_(in_3))), xor(and_(in_4, in_5), in_2)))), and_(or_(in_5, xor(or_(in_2, xor(and_(not_(and_(or_(in_5, in_4), 1)), or_(or_(in_1, in_1), in_5)), or_(in_4, xor(not_(in_4), xor(0, or_(in_1, or_(in_3, or_(or_(in_0, 1), in_2)))))))), in_4)), not_(and_(in_5, in_5))))
# -- length=78, height=13
# -- Best Fitness =  4.0
#
#
# Currently on run 12 of 30
#    	      	                    fitness                     	                     size
#    	      	------------------------------------------------	----------------------------------------------
# gen	nevals	avg    	gen	max	min	nevals	std     	avg   	gen	max	min	nevals	std
# 0  	2000  	31.9955	0  	44 	16 	2000  	0.910758	23.229	0  	62 	4  	2000  	13.482
# 1  	1797  	31.887 	1  	40 	16 	1797  	0.890635	23.1475	1  	73 	1  	1797  	13.8491
# 2  	1815  	31.8585	2  	40 	16 	1815  	0.973385	24.0345	2  	80 	1  	1815  	14.7062
# 3  	1797  	31.868 	3  	40 	24 	1797  	0.863467	24.6825	3  	86 	1  	1797  	15.2863
# 4  	1774  	31.8   	4  	40 	22 	1774  	0.970052	25.626 	4  	89 	1  	1774  	16.1159
# 5  	1835  	31.7475	5  	44 	22 	1835  	1.20156 	27.5825	5  	87 	1  	1835  	17.3709
# 6  	1804  	31.687 	6  	48 	16 	1804  	1.39213 	29.267 	6  	100	1  	1804  	18.3155
# 7  	1797  	31.557 	7  	40 	16 	1797  	1.51616 	32.556 	7  	104	1  	1797  	19.793
# 8  	1762  	31.4975	8  	48 	16 	1762  	1.6389  	34.5415	8  	111	1  	1762  	21.0052
# 9  	1819  	31.292 	9  	44 	20 	1819  	1.71019 	38.5075	9  	123	1  	1819  	22.1166
# 10 	1757  	31.1445	10 	40 	20 	1757  	1.87313 	44.1175	10 	128	1  	1757  	23.7013
# 11 	1823  	30.908 	11 	44 	18 	1823  	2.15651 	48.493 	11 	148	1  	1823  	24.283
# 12 	1773  	30.6415	12 	40 	18 	1773  	2.25499 	52.984 	12 	135	1  	1773  	24.5844
# 13 	1801  	30.3195	13 	40 	16 	1801  	2.55703 	57.3615	13 	140	2  	1801  	24.7176
# 14 	1805  	30.1485	14 	42 	16 	1805  	2.68318 	61.0725	14 	155	2  	1805  	26.1695
# 15 	1816  	29.9085	15 	42 	16 	1816  	2.79287 	64.987 	15 	171	3  	1816  	26.797
# 16 	1814  	29.6345	16 	40 	16 	1814  	2.9636  	68.336 	16 	171	3  	1814  	27.2702
# 17 	1800  	29.215 	17 	42 	16 	1800  	3.2611  	73.683 	17 	170	3  	1800  	27.8736
# 18 	1817  	28.9255	18 	44 	16 	1817  	3.49384 	76.842 	18 	187	3  	1817  	28.5057
# 19 	1780  	28.4355	19 	42 	16 	1780  	3.64922 	80.116 	19 	189	1  	1780  	28.5679
# 20 	1790  	28.043 	20 	48 	16 	1790  	3.86396 	82.704 	20 	173	3  	1790  	28.9015
# 21 	1783  	27.566 	21 	44 	16 	1783  	4.07144 	86.555 	21 	195	3  	1783  	30.3285
# 22 	1791  	27.099 	22 	44 	0  	1791  	4.09819 	90.106 	22 	211	1  	1791  	30.6777
# 23 	1780  	26.5955	23 	44 	16 	1780  	4.2418  	93.337 	23 	211	1  	1780  	31.6085
# 24 	1816  	26.102 	24 	42 	16 	1816  	4.42771 	97.898 	24 	208	1  	1816  	32.1768
# 25 	1832  	25.6345	25 	44 	16 	1832  	4.55565 	101.567	25 	208	7  	1832  	33.2605
# 26 	1804  	25.0785	26 	44 	8  	1804  	4.66598 	105.219	26 	216	6  	1804  	34.561
# 27 	1826  	24.5835	27 	42 	8  	1826  	4.72208 	109.373	27 	238	4  	1826  	35.5861
# 28 	1805  	24.0875	28 	46 	8  	1805  	4.86609 	111.938	28 	238	1  	1805  	35.2507
# 29 	1839  	23.613 	29 	44 	8  	1839  	5.15609 	115.61 	29 	243	14 	1839  	36.0906
# 30 	1778  	22.9255	30 	46 	8  	1778  	5.15916 	119.48 	30 	257	5  	1778  	36.6711
# -- Best Individual =  xor(xor(or_(not_(1), not_(not_(in_3))), or_(not_(and_(in_4, in_2)), or_(xor(in_1, 1), not_(in_4)))), xor(or_(or_(and_(0, or_(xor(in_1, 1), not_(or_(0, in_0)))), and_(in_2, in_4)), or_(not_(xor(or_(in_1, and_(in_0, and_(not_(in_0), not_(or_(1, in_0))))), xor(in_4, in_2))), not_(1))), or_(xor(not_(in_5), not_(in_0)), and_(or_(in_5, in_0), xor(xor(xor(in_2, in_2), or_(in_5, or_(in_5, in_4))), in_5)))))
# -- length=75, height=11
# -- Best Fitness =  0.0
#
#
# Currently on run 13 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg   	gen	max	min	nevals	std     	avg    	gen	max	min	nevals	std
# 0  	2000  	31.982	0  	38 	24 	2000  	0.720886	23.5145	0  	62 	4  	2000  	13.7708
# 1  	1799  	31.89 	1  	35 	24 	1799  	0.666258	23.7995	1  	72 	2  	1799  	14.4227
# 2  	1801  	31.875	2  	40 	24 	1801  	0.862192	24.668 	2  	88 	1  	1801  	15.0723
# 3  	1775  	31.808	3  	40 	20 	1775  	1.02671 	26.196 	3  	88 	1  	1775  	16.3612
# 4  	1792  	31.74 	4  	38 	16 	1792  	1.18887 	28.046 	4  	88 	1  	1792  	17.0407
# 5  	1784  	31.694	5  	40 	16 	1784  	1.36138 	29.7635	5  	90 	1  	1784  	18.0772
# 6  	1793  	31.6025	6  	48 	16 	1793  	1.53639 	31.5535	6  	110	1  	1793  	18.8815
# 7  	1798  	31.4985	7  	40 	16 	1798  	1.65711 	34.6245	7  	108	1  	1798  	19.9794
# 8  	1787  	31.408 	8  	48 	16 	1787  	1.78565 	37.211 	8  	110	1  	1787  	20.9352
# 9  	1821  	31.291 	9  	48 	16 	1821  	1.89956 	40.368 	9  	110	1  	1821  	21.7255
# 10 	1824  	31.112 	10 	40 	16 	1824  	2.04511 	44.2935	10 	126	1  	1824  	22.4759
# 11 	1803  	30.887 	11 	41 	16 	1803  	2.26677 	48.4725	11 	133	1  	1803  	23.2315
# 12 	1779  	30.592 	12 	40 	16 	1779  	2.38758 	52.9   	12 	155	1  	1779  	23.8793
# 13 	1795  	30.448 	13 	44 	16 	1795  	2.51143 	57.861 	13 	176	1  	1795  	24.9888
# 14 	1765  	30.245 	14 	44 	16 	1765  	2.64764 	61.87  	14 	208	1  	1765  	25.1807
# 15 	1813  	29.95  	15 	41 	16 	1813  	2.85228 	65.451 	15 	198	1  	1813  	25.0928
# 16 	1826  	29.597 	16 	45 	16 	1826  	3.08976 	68.652 	16 	198	1  	1826  	25.5067
# 17 	1808  	29.1555	17 	46 	16 	1808  	3.21952 	72.297 	17 	198	1  	1808  	26.2636
# 18 	1793  	28.716 	18 	48 	16 	1793  	3.46603 	76.31  	18 	192	3  	1793  	26.9574
# 19 	1784  	28.4635	19 	48 	16 	1784  	3.6019  	79.1655	19 	196	3  	1784  	27.6782
# 20 	1773  	28.1825	20 	44 	16 	1773  	3.74649 	81.6615	20 	247	5  	1773  	28.5782
# 21 	1813  	27.898 	21 	42 	12 	1813  	3.93594 	83.471 	21 	203	5  	1813  	29.698
# 22 	1821  	27.3765	22 	48 	14 	1821  	4.04929 	86.272 	22 	240	5  	1821  	30.2025
# 23 	1825  	27.079 	23 	41 	12 	1825  	4.15304 	87.654 	23 	219	4  	1825  	30.9437
# 24 	1782  	26.8095	24 	52 	11 	1782  	4.48087 	88.7265	24 	289	5  	1782  	31.7931
# 25 	1814  	26.563 	25 	56 	0  	1814  	4.55676 	90.193 	25 	261	3  	1814  	32.9075
# 26 	1816  	26.1985	26 	52 	0  	1816  	4.84263 	91.565 	26 	263	3  	1816  	33.3871
# 27 	1773  	25.922 	27 	48 	0  	1773  	5.13867 	94.022 	27 	263	5  	1773  	33.2307
# 28 	1787  	25.357 	28 	53 	4  	1787  	5.22279 	95.9445	28 	256	5  	1787  	33.8469
# 29 	1803  	25.2105	29 	44 	0  	1803  	5.31772 	96.12  	29 	215	3  	1803  	34.5593
# 30 	1787  	24.6945	30 	48 	2  	1787  	5.46637 	97.364 	30 	229	8  	1787  	34.5386
# -- Best Individual =  xor(xor(or_(xor(not_(in_4), in_5), xor(in_4, in_4)), or_(xor(xor(and_(in_2, in_0), and_(in_0, in_3)), not_(in_4)), and_(xor(xor(in_4, in_3), in_3), or_(and_(0, or_(in_0, 1)), xor(in_5, in_5))))), not_(not_(xor(xor(in_4, in_1), or_(xor(in_3, in_2), in_0)))))
# -- length=47, height=7
# -- Best Fitness =  0.0
#
#
# Currently on run 14 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg    	gen	max	min	nevals	std     	avg    	gen	max	min	nevals	std
# 0  	2000  	31.9965	0  	43 	24 	2000  	0.787075	22.9155	0  	61 	4  	2000  	13.4561
# 1  	1787  	31.953 	1  	48 	24 	1787  	0.817185	22.9085	1  	71 	1  	1787  	13.9944
# 2  	1810  	31.9205	2  	40 	20 	1810  	0.916613	23.5725	2  	77 	1  	1810  	14.5579
# 3  	1801  	31.8625	3  	40 	16 	1801  	0.986709	24.3065	3  	111	1  	1801  	15.1613
# 4  	1783  	31.8375	4  	40 	24 	1783  	0.93386 	25.1195	4  	111	1  	1783  	16.0405
# 5  	1796  	31.8025	5  	56 	16 	1796  	1.2343  	26.136 	5  	113	1  	1796  	16.3979
# 6  	1806  	31.7655	6  	48 	24 	1806  	1.2184  	27.702 	6  	96 	1  	1806  	17.4704
# 7  	1801  	31.667 	7  	48 	18 	1801  	1.58906 	30.2255	7  	96 	1  	1801  	18.7583
# 8  	1803  	31.5085	8  	38 	18 	1803  	1.56618 	32.987 	8  	111	1  	1803  	20.2183
# 9  	1800  	31.3495	9  	48 	16 	1800  	1.9296  	36.0015	9  	112	1  	1800  	22.0664
# 10 	1807  	31.1485	10 	44 	16 	1807  	2.08601 	40.5715	10 	144	1  	1807  	23.4927
# 11 	1779  	30.726 	11 	40 	16 	1779  	2.41411 	46.2055	11 	167	1  	1779  	24.524
# 12 	1783  	30.388 	12 	48 	16 	1783  	2.85718 	52.138 	12 	170	1  	1783  	25.2778
# 13 	1792  	29.971 	13 	45 	8  	1792  	3.33259 	56.289 	13 	171	1  	1792  	25.9033
# 14 	1800  	29.5415	14 	44 	8  	1800  	3.46804 	60.9125	14 	171	1  	1800  	25.8675
# 15 	1806  	28.9125	15 	46 	8  	1806  	3.93495 	65.0145	15 	184	1  	1806  	25.4867
# ...
# 7  	1823  	31.751 	7  	40 	20 	1823  	1.20416 	28.7245	7  	105	1  	1823  	18.6638
# 8  	1782  	31.7075	8  	42 	20 	1782  	1.19664 	30.793 	8  	115	1  	1782  	20.227
# 9  	1818  	31.5975	9  	38 	21 	1818  	1.34331 	32.994 	9  	112	1  	1818  	21.1862
# 10 	1809  	31.4945	10 	40 	20 	1809  	1.49866 	36.501 	10 	119	1  	1809  	23.1464
# 11 	1810  	31.3455	11 	48 	16 	1810  	1.73468 	40.3105	11 	131	1  	1810  	24.5911
# 12 	1824  	31.1555	12 	44 	16 	1824  	1.93296 	44.682 	12 	130	1  	1824  	24.9944
# 13 	1818  	30.8995	13 	40 	16 	1818  	2.19782 	49.9205	13 	146	1  	1818  	26.691
# 14 	1782  	30.618 	14 	40 	16 	1782  	2.47832 	54.517 	14 	155	1  	1782  	26.7392
# 15 	1784  	30.3355	15 	48 	8  	1784  	2.77866 	60.395 	15 	157	1  	1784  	27.525
# 16 	1818  	30.2335	16 	42 	16 	1818  	2.81229 	64.0535	16 	196	1  	1818  	27.7367
# 17 	1791  	29.97  	17 	44 	16 	1791  	3.02838 	68.5915	17 	169	2  	1791  	27.877
# 18 	1828  	29.5275	18 	41 	14 	1828  	3.2882  	73.724 	18 	169	1  	1828  	28.4768
# 19 	1829  	29.227 	19 	44 	16 	1829  	3.59047 	78.1175	19 	170	3  	1829  	29.2342
# 20 	1811  	28.6675	20 	41 	9  	1811  	3.77517 	82.4705	20 	181	3  	1811  	29.844
# 21 	1814  	28.0825	21 	44 	10 	1814  	3.98242 	85.7525	21 	199	3  	1814  	30.0833
# 22 	1806  	27.712 	22 	56 	8  	1806  	4.48242 	87.7255	22 	201	3  	1806  	31.0999
# 23 	1807  	27.13  	23 	44 	8  	1807  	4.67965 	90.803 	23 	203	1  	1807  	32.0336
# 24 	1782  	26.4175	24 	44 	8  	1782  	5.07565 	91.128 	24 	205	4  	1782  	31.7201
# 25 	1806  	25.71  	25 	48 	8  	1806  	5.42115 	91.9305	25 	225	3  	1806  	32.307
# 26 	1813  	25.1215	26 	46 	8  	1813  	5.92045 	92.9005	26 	225	4  	1813  	33.1779
# 27 	1821  	24.3135	27 	50 	8  	1821  	6.26157 	93.143 	27 	225	1  	1821  	34.1358
# 28 	1794  	23.209 	28 	48 	8  	1794  	6.64826 	93.715 	28 	225	3  	1794  	35.1796
# 29 	1789  	22.229 	29 	56 	7  	1789  	7.06028 	94.037 	29 	256	4  	1789  	37.3126
# 30 	1821  	21.5525	30 	48 	7  	1821  	7.3288  	94.1815	30 	256	1  	1821  	39.7115
# -- Best Individual =  xor(not_(xor(xor(or_(or_(or_(not_(xor(and_(in_2, in_5), or_(and_(1, or_(not_(not_(in_2)), or_(or_(in_0, 1), and_(not_(in_1), or_(in_1, in_3))))), in_5))), and_(and_(xor(0, in_1), not_(in_0)), or_(and_(in_5, in_2), and_(in_2, in_4)))), in_5), in_4), xor(in_2, in_0)), xor(xor(1, in_1), not_(in_4)))), and_(or_(and_(and_(in_2, not_(0)), not_(not_(not_(0)))), or_(or_(xor(not_(in_3), xor(not_(and_(not_(xor(in_4, or_(xor(not_(in_5), not_(and_(not_(and_(in_0, in_2)), or_(xor(in_3, in_1), 0)))), in_2))), not_(xor(or_(in_4, xor(in_3, in_2)), and_(not_(in_3), not_(in_5)))))), 1)), not_(xor(xor(or_(or_(and_(0, in_5), not_(or_(in_3, not_(in_1)))), in_2), or_(in_2, 1)), not_(and_(or_(not_(not_(in_2)), in_5), in_5))))), in_0)), or_(not_(in_3), xor(or_(in_4, in_5), xor(in_5, 0)))))
# -- length=142, height=17
# -- Best Fitness =  7.0
#
#
# Currently on run 26 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg    	gen	max	min	nevals	std     	avg    	gen	max	min	nevals	std
# 0  	2000  	32.0085	0  	41 	20 	2000  	0.710934	22.6615	0  	61 	4  	2000  	13.2328
# 1  	1797  	31.9455	1  	40 	24 	1797  	0.599608	22.641 	1  	67 	1  	1797  	13.6445
# 2  	1790  	31.9295	2  	36 	24 	1790  	0.67567 	23.2745	2  	83 	1  	1790  	14.571
# 3  	1779  	31.927 	3  	40 	24 	1779  	0.738018	24.3375	3  	75 	1  	1779  	15.3188
# 4  	1792  	31.9225	4  	48 	24 	1792  	0.843501	24.892 	4  	84 	1  	1792  	16.0027
# 5  	1780  	31.8615	5  	42 	24 	1780  	0.955153	25.8655	5  	96 	1  	1780  	17.329
# 6  	1771  	31.785 	6  	40 	24 	1771  	1.09168 	26.7885	6  	96 	1  	1771  	18.4264
# 7  	1803  	31.753 	7  	40 	16 	1803  	1.29228 	28.379 	7  	109	1  	1803  	19.1587
# 8  	1828  	31.5985	8  	44 	16 	1828  	1.58817 	31.408 	8  	115	1  	1828  	20.5202
# 9  	1805  	31.416 	9  	44 	16 	1805  	1.79581 	35.066 	9  	117	1  	1805  	21.5485
# 10 	1793  	31.2325	10 	44 	16 	1793  	2.10747 	38.857 	10 	153	1  	1793  	22.723
# 11 	1784  	31.0045	11 	40 	14 	1784  	2.32303 	42.848 	11 	160	1  	1784  	23.5614
# 12 	1784  	30.695 	12 	44 	14 	1784  	2.51813 	47.985 	12 	152	1  	1784  	24.2976
# 13 	1806  	30.413 	13 	40 	12 	1806  	2.79632 	53.256 	13 	172	1  	1806  	25.2452
# 14 	1822  	30.0525	14 	56 	16 	1822  	2.90375 	58.5365	14 	178	1  	1822  	24.5424
# 15 	1776  	29.7625	15 	48 	13 	1776  	3.11658 	61.97  	15 	158	1  	1776  	24.8748
# 16 	1808  	29.5   	16 	48 	12 	1808  	3.38172 	64.302 	16 	160	2  	1808  	25.2372
# 17 	1823  	29.081 	17 	40 	0  	1823  	3.67783 	66.881 	17 	175	2  	1823  	25.4904
# 18 	1817  	28.593 	18 	40 	12 	1817  	3.94682 	68.5515	18 	175	1  	1817  	26.195
# 19 	1812  	28.102 	19 	48 	8  	1812  	4.28364 	71.384 	19 	177	5  	1812  	27.1958
# 20 	1831  	27.7445	20 	48 	8  	1831  	4.7064  	73.091 	20 	198	3  	1831  	27.9933
# 21 	1796  	27.23  	21 	48 	8  	1796  	4.82422 	75.9115	21 	200	1  	1796  	28.3005
# 22 	1823  	26.6805	22 	60 	8  	1823  	5.06216 	77.462 	22 	198	5  	1823  	29.0097
# 23 	1787  	25.9605	23 	48 	8  	1787  	5.35705 	80.158 	23 	208	3  	1787  	29.3372
# 24 	1816  	24.938 	24 	44 	0  	1816  	5.6761  	84.17  	24 	177	3  	1816  	28.8239
# 25 	1800  	24.32  	25 	52 	0  	1800  	6.16933 	87.336 	25 	183	4  	1800  	29.805
# 26 	1772  	23.5705	26 	52 	0  	1772  	6.6459  	89.779 	26 	185	5  	1772  	29.9216
# 27 	1791  	22.5495	27 	52 	0  	1791  	6.86947 	92.698 	27 	185	4  	1791  	30.1578
# 28 	1785  	21.3755	28 	50 	0  	1785  	6.92398 	95.3575	28 	222	3  	1785  	31.192
# 29 	1799  	20.748 	29 	48 	0  	1799  	7.18453 	97.1995	29 	236	3  	1799  	32.4436
# 30 	1807  	20.0695	30 	56 	0  	1807  	7.47507 	98.4995	30 	237	5  	1807  	32.5538
# -- Best Individual =  and_(xor(or_(and_(1, and_(in_5, 1)), xor(not_(in_5), xor(1, in_5))), not_(in_5)), xor(xor(not_(or_(1, in_0)), in_4), xor(xor(xor(in_3, in_1), and_(1, and_(xor(and_(in_2, 1), in_5), 1))), or_(not_(1), in_0))))
# -- length=41, height=8
# -- Best Fitness =  0.0
#
#
# Currently on run 27 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg    	gen	max	min	nevals	std     	avg    	gen	max	min	nevals	std
# 0  	2000  	31.9765	0  	40 	8  	2000  	0.958618	22.7585	0  	62 	4  	2000  	13.2578
# 1  	1772  	31.932 	1  	40 	4  	1772  	0.892959	22.4915	1  	65 	1  	1772  	13.0526
# 2  	1797  	31.906 	2  	54 	4  	1797  	1.26062 	22.7055	2  	84 	1  	1797  	13.811
# 3  	1815  	31.8825	3  	48 	4  	1815  	1.12947 	22.881 	3  	84 	1  	1815  	13.9445
# 4  	1799  	31.827 	4  	40 	4  	1799  	1.25183 	23.6265	4  	84 	1  	1799  	14.5722
# 5  	1789  	31.79  	5  	40 	16 	1789  	1.12734 	24.723 	5  	87 	1  	1789  	15.315
# 6  	1805  	31.7725	6  	40 	16 	1805  	1.14967 	25.776 	6  	88 	1  	1805  	16.0491
# 7  	1799  	31.7385	7  	40 	19 	1799  	1.19085 	27.821 	7  	104	1  	1799  	17.4942
# 8  	1818  	31.658 	8  	40 	16 	1818  	1.37297 	29.97  	8  	106	1  	1818  	18.6832
# 9  	1804  	31.5595	9  	44 	16 	1804  	1.66507 	32.4395	9  	114	1  	1804  	20.2887
# 10 	1815  	31.3745	10 	40 	14 	1815  	1.83473 	35.333 	10 	138	1  	1815  	22.4023
# 11 	1807  	31.2295	11 	40 	14 	1807  	2.07601 	38.0155	11 	138	1  	1807  	24.3343
# 12 	1832  	31.162 	12 	50 	10 	1832  	2.27854 	41.7595	12 	141	1  	1832  	25.769
# 13 	1787  	30.8645	13 	48 	14 	1787  	2.3833  	46.2705	13 	141	1  	1787  	26.2138
# 14 	1799  	30.6425	14 	48 	14 	1799  	2.61967 	51.1525	14 	158	1  	1799  	27.2767
# 15 	1817  	30.1675	15 	42 	12 	1817  	2.89006 	56.594 	15 	162	1  	1817  	27.0875
# 16 	1805  	30.0285	16 	52 	12 	1805  	3.16539 	61.2985	16 	155	1  	1805  	27.8598
# 17 	1815  	29.629 	17 	48 	8  	1815  	3.34355 	64.762 	17 	162	1  	1815  	28.4429
# 18 	1800  	29.1025	18 	40 	14 	1800  	3.54979 	68.2065	18 	177	1  	1800  	28.3919
# 19 	1822  	28.603 	19 	48 	14 	1822  	3.89543 	71.9075	19 	185	1  	1822  	29.8012
# 20 	1790  	27.8485	20 	45 	12 	1790  	4.388   	77.0035	20 	177	3  	1790  	30.572
# 21 	1812  	27.1125	21 	50 	12 	1812  	4.7357  	80.5975	21 	197	3  	1812  	31.3457
# 22 	1780  	26.0495	22 	48 	8  	1780  	5.18518 	83.605 	22 	187	3  	1780  	31.9263
# 23 	1802  	25.152 	23 	48 	8  	1802  	5.57296 	86.519 	23 	199	3  	1802  	33.238
# 24 	1795  	24.2945	24 	47 	8  	1795  	5.89498 	87.158 	24 	217	3  	1795  	34.4818
# 25 	1814  	22.964 	25 	49 	8  	1814  	5.98212 	89.859 	25 	224	1  	1814  	34.5594
# 26 	1796  	21.847 	26 	48 	8  	1796  	6.23062 	91.3305	26 	219	1  	1796  	33.998
# 27 	1815  	21.123 	27 	49 	8  	1815  	6.63414 	92.608 	27 	222	1  	1815  	35.2068
# 28 	1799  	20.279 	28 	56 	8  	1799  	6.8369  	95.4235	28 	214	3  	1799  	35.4259
# 29 	1823  	19.234 	29 	46 	0  	1823  	6.69038 	95.5445	29 	219	10 	1823  	34.9991
# 30 	1774  	18.342 	30 	53 	0  	1774  	6.92683 	97.8615	30 	271	12 	1774  	35.5494
# -- Best Individual =  xor(xor(xor(or_(in_0, and_(in_4, in_0)), and_(or_(in_3, in_5), xor(in_3, in_5))), or_(xor(not_(in_4), xor(in_1, in_2)), and_(and_(and_(in_4, in_3), in_1), and_(or_(not_(in_5), in_0), 0)))), or_(or_(xor(xor(in_3, not_(in_2)), not_(in_4)), xor(xor(in_0, in_0), and_(and_(or_(not_(xor(0, in_4)), or_(0, in_2)), and_(or_(in_4, in_4), or_(in_1, not_(and_(xor(1, in_3), or_(in_2, in_0)))))), xor(xor(not_(in_4), or_(not_(or_(in_4, xor(or_(in_4, 1), in_2))), in_1)), xor(or_(and_(in_5, xor(in_5, in_1)), in_4), not_(xor(and_(in_0, in_3), or_(0, xor(or_(in_0, in_2), and_(in_0, in_4)))))))))), not_(0)))
# -- length=109, height=12
# -- Best Fitness =  0.0
#
#
# Currently on run 28 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg   	gen	max	min	nevals	std     	avg    	gen	max	min	nevals	std
# 0  	2000  	31.982	0  	40 	24 	2000  	0.716014	22.9625	0  	63 	4  	2000  	13.3231
# 1  	1801  	31.929	1  	48 	24 	1801  	0.768088	22.936 	1  	69 	1  	1801  	13.4325
# 2  	1828  	31.909	2  	48 	24 	1828  	0.816529	23.5485	2  	81 	1  	1828  	14.3074
# 3  	1764  	31.88 	3  	40 	24 	1764  	0.868101	23.0885	3  	83 	1  	1764  	14.7346
# 4  	1799  	31.8525	4  	40 	24 	1799  	0.832913	23.7525	4  	90 	1  	1799  	15.5874
# 5  	1799  	31.8065	5  	42 	16 	1799  	1.11133 	24.568 	5  	88 	1  	1799  	16.4768
# 6  	1779  	31.7355	6  	40 	20 	1779  	1.20106 	25.7975	6  	94 	1  	1779  	17.2738
# 7  	1772  	31.5995	7  	40 	20 	1772  	1.37626 	27.5125	7  	94 	1  	1772  	18.1875
# 8  	1830  	31.503 	8  	41 	12 	1830  	1.69145 	30.2695	8  	108	1  	1830  	19.5335
# 9  	1775  	31.297 	9  	40 	12 	1775  	2.0002  	33.281 	9  	110	1  	1775  	21.0105
# 10 	1809  	31.1525	10 	40 	12 	1809  	2.22469 	36.561 	10 	111	1  	1809  	21.5593
# 11 	1822  	30.954 	11 	40 	12 	1822  	2.39935 	40.908 	11 	124	1  	1822  	22.5753
# 12 	1789  	30.7665	12 	44 	16 	1789  	2.5385  	44.9605	12 	128	1  	1789  	22.7464
# 13 	1787  	30.5805	13 	44 	16 	1787  	2.66543 	49.303 	13 	136	2  	1787  	23.2959
# 14 	1778  	30.1965	14 	46 	16 	1778  	2.89964 	53.5765	14 	155	2  	1778  	23.988
# 15 	1794  	29.844 	15 	44 	12 	1794  	3.17075 	58.0885	15 	158	1  	1794  	24.7586
# 16 	1771  	29.364 	16 	40 	12 	1771  	3.33444 	62.453 	16 	153	1  	1771  	25.0247
# 17 	1806  	29.0265	17 	44 	6  	1806  	3.68806 	66.0085	17 	166	1  	1806  	25.3746
# 18 	1784  	28.529 	18 	48 	6  	1784  	3.96688 	68.6775	18 	174	1  	1784  	26.3253
# 19 	1791  	27.889 	19 	40 	4  	1791  	4.32905 	71.5305	19 	173	3  	1791  	27.2513
# 20 	1805  	27.2975	20 	46 	0  	1805  	4.93356 	74.8545	20 	172	3  	1805  	27.6603
# 21 	1813  	26.6095	21 	44 	0  	1813  	5.39833 	77.695 	21 	173	3  	1813  	27.0911
# 22 	1806  	25.786 	22 	48 	0  	1806  	5.75536 	79.2875	22 	179	2  	1806  	27.3336
# 23 	1827  	25.108 	23 	56 	0  	1827  	6.05585 	78.8905	23 	188	3  	1827  	28.4646
# 24 	1821  	24.536 	24 	48 	0  	1821  	6.51319 	80.617 	24 	211	3  	1821  	30.2066
# 25 	1803  	23.684 	25 	48 	0  	1803  	7.02404 	81.834 	25 	191	3  	1803  	30.2801
# 26 	1783  	22.4885	26 	64 	0  	1783  	7.62265 	82.776 	26 	184	11 	1783  	29.6604
# 27 	1824  	21.4845	27 	48 	0  	1824  	7.93623 	83.284 	27 	202	7  	1824  	29.7738
# 28 	1797  	20.358 	28 	56 	0  	1797  	8.46864 	84.289 	28 	200	3  	1797  	30.3441
# 29 	1811  	19.4895	29 	60 	0  	1811  	8.82881 	86.151 	29 	202	4  	1811  	30.6949
# 30 	1814  	18.527 	30 	64 	0  	1814  	9.19904 	88.376 	30 	251	1  	1814  	30.3906
# -- Best Individual =  or_(xor(xor(not_(or_(0, xor(in_1, in_4))), in_3), and_(xor(not_(in_0), xor(in_5, or_(in_2, and_(in_2, 1)))), or_(or_(in_1, in_2), xor(1, in_2)))), xor(or_(or_(not_(xor(or_(in_4, xor(in_0, in_1)), in_3)), xor(1, in_5)), 1), or_(or_(xor(or_(in_4, 0), not_(in_5)), not_(0)), and_(and_(in_2, in_3), in_4))))
# -- length=58, height=8
# -- Best Fitness =  0.0
#
#
# Currently on run 29 of 30
#    	      	                    fitness                     	                      size
#    	      	------------------------------------------------	-----------------------------------------------
# gen	nevals	avg    	gen	max	min	nevals	std     	avg   	gen	max	min	nevals	std
# 0  	2000  	32.0055	0  	48 	20 	2000  	0.882876	22.569	0  	62 	4  	2000  	13.3745
# 1  	1787  	31.919 	1  	36 	24 	1787  	0.681498	22.361	1  	72 	1  	1787  	13.4166
# 2  	1823  	31.9135	2  	40 	24 	1823  	0.825238	23.148	2  	83 	1  	1823  	14.3867
# 3  	1823  	31.8485	3  	40 	24 	1823  	0.856474	24.027	3  	88 	1  	1823  	15.0554
# 4  	1792  	31.8125	4  	40 	24 	1792  	0.927547	25.6205	4  	93 	1  	1792  	16.2452
# 5  	1819  	31.732 	5  	48 	24 	1819  	1.13012 	27.123 	5  	104	1  	1819  	17.5757
# 6  	1775  	31.5915	6  	38 	20 	1775  	1.33814 	29.2485	6  	106	1  	1775  	19.0494
# 7  	1800  	31.494 	7  	40 	12 	1800  	1.59278 	32.1715	7  	105	1  	1800  	20.6453
# 8  	1778  	31.3815	8  	40 	12 	1778  	1.72886 	36.602 	8  	112	1  	1778  	22.0106
# 9  	1807  	31.2345	9  	48 	12 	1807  	1.91481 	40.4175	9  	115	1  	1807  	22.9537
# 10 	1778  	30.997 	10 	40 	8  	1778  	2.07846 	44.7425	10 	131	1  	1778  	23.3551
# 11 	1787  	30.8065	11 	48 	8  	1787  	2.41786 	48.7565	11 	130	1  	1787  	23.7346
# 12 	1837  	30.5205	12 	41 	8  	1837  	2.6417  	53.9565	12 	130	1  	1837  	24.2502
# 13 	1808  	30.222 	13 	42 	8  	1808  	2.81722 	58.99  	13 	139	1  	1808  	25.4395
# 14 	1799  	29.892 	14 	42 	8  	1799  	3.19066 	63.1965	14 	157	1  	1799  	26.173
# 15 	1804  	29.809 	15 	45 	8  	1804  	3.37158 	66.642 	15 	159	1  	1804  	26.8084
# 16 	1780  	29.2795	16 	44 	8  	1780  	3.59074 	69.8915	16 	162	3  	1780  	28.4959
# 17 	1774  	28.8225	17 	52 	8  	1774  	3.80539 	74.983 	17 	189	2  	1774  	29.5521
# 18 	1819  	28.516 	18 	48 	8  	1819  	3.9764  	75.802 	18 	181	1  	1819  	30.6019
# 19 	1772  	28.0275	19 	41 	8  	1772  	3.99396 	78.4565	19 	206	3  	1772  	31.0725
# 20 	1781  	27.3945	20 	45 	6  	1781  	4.46395 	81.831 	20 	230	3  	1781  	30.9657
# 21 	1817  	26.9785	21 	48 	6  	1817  	4.54786 	84.0015	21 	227	2  	1817  	31.8853
# 22 	1807  	26.45  	22 	44 	6  	1807  	4.66749 	87.093 	22 	231	1  	1807  	33.9849
# 23 	1766  	25.891 	23 	48 	6  	1766  	4.90215 	91.053 	23 	231	2  	1766  	34.9292
# 24 	1787  	25.3915	24 	50 	4  	1787  	5.45319 	93.935 	24 	208	3  	1787  	34.507
# 25 	1798  	24.6065	25 	42 	4  	1798  	5.53838 	97.336 	25 	246	2  	1798  	34.7192
# 26 	1808  	23.887 	26 	48 	3  	1808  	6.07892 	99.019 	26 	249	13 	1808  	35.5724
# 27 	1790  	23.284 	27 	49 	4  	1790  	6.44479 	100.738	27 	264	1  	1790  	36.6056
# 28 	1800  	22.526 	28 	48 	0  	1800  	6.76634 	102.077	28 	276	2  	1800  	37.326
# 29 	1800  	21.3955	29 	50 	0  	1800  	7.0187  	103.179	29 	292	8  	1800  	39.1486
# 30 	1796  	20.7075	30 	50 	0  	1796  	7.38539 	104.326	30 	295	8  	1796  	40.2844
# -- Best Individual =  or_(xor(or_(xor(and_(in_3, in_4), or_(and_(or_(in_2, 1), or_(not_(0), 1)), not_(not_(and_(0, in_0))))), 1), or_(xor(xor(in_2, or_(not_(xor(in_2, in_5)), 0)), or_(0, in_3)), 1)), xor(xor(in_3, or_(0, xor(in_5, in_4))), xor(xor(or_(in_1, in_1), not_(in_0)), xor(not_(0), xor(in_2, 0)))))
# -- length=57, height=8
# -- Best Fitness =  0.0

# %% [markdown]
# Create our graphs using the averages across all the runs. Notice how we use standard deviation to show how much variation there is in the runs.

# %%
# Genetic Programming is done (all runs) - plot statistics:
x = numpy.arange(0, MAX_GENERATIONS+1)
avgArray = numpy.array(avgListFitness)
stdArray = numpy.array(stdListFitness)
minArray = numpy.array(minListFitness)
maxArray = numpy.array(maxListFitness)
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('Best and Average Fitness for Even Parity')
plt.errorbar(x, avgArray.mean(0), yerr=stdArray.mean(0),label="Average",color="Red")
plt.errorbar(x, minArray.mean(0), yerr=minArray.std(0),label="Best", color="Green")
plt.show()

# %% [markdown]
# Show the graph for size.

# %%
# Genetic Programming is done (all runs) - plot statistics:
x = numpy.arange(0, MAX_GENERATIONS+1)
avgArray = numpy.array(avgListS)
stdArray = numpy.array(stdListFitness)
minArray = numpy.array(minListFitness)
maxArray = numpy.array(maxListFitness)
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.title('Max and Average Fitness for Even Parity')
plt.errorbar(x, avgArray.mean(0), yerr=stdArray.mean(0),label="Average",color="Red")
plt.errorbar(x, minArray.mean(0), yerr=minArray.std(0),label="Best", color="Green")
plt.show()
